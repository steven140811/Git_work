# %% [markdown]
# ### 代码说明：
# * subway.xlsx 地铁线路站点名称及经纬度数据
#
# * graph.pkl 记录站点与站点两两之间的距离
#
# * preprocessing_location.py 封装了get_page_content(request_url)从网页获取地铁站信息、content_analysis()网站内容解析、    get_location(keyword,city)获取经纬度、work()将经纬度插入到subway.xlsx中
#
# * Route_api.py 封装了find_lowest_cost_node(costs)找到最小开销节点、find_shortest_path()找到最短路径、compute(site1,site2) + dijkstra()计算从start到end的最短路径
#
# * main.py 封装了get_nearest_subway(data,longitude1,latitude1)找最近的地铁站、compute(site1,site2,city)计算从site1到site2的最短路径

# %% [markdown]
# ### 获取地铁站数据

# %%
# 获得指定城市的地铁路线
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_page_content(request_url):
    #得到页面内容
    header={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36'}
    html = requests.get(request_url,headers=header,timeout=10)
    content = html.text
    # print(content)
    # 通过content创建BS对象
    # html.parser是bs自带的html解析器
    soup = BeautifulSoup(content,'html.parser',from_encoding='utf-8')
    return soup
    
request_url = 'https://ditie.mapbar.com/beijing_line/'
soup = get_page_content(request_url)

# 解析内容
subways = soup.find_all('div',class_='station')
df = pd.DataFrame(columns=['name','site'])
for subway in subways:
    # 得到线路名称
    route_name = subway.find('strong',class_='bolder').text
    # print('routename = ',route_name)
    # 找到该线路中每一站的名称
    routes = subway.find('ul')
    routes = routes.find_all('a')
    for route in routes:
        # name 地铁站名 site 线路名
        temp = {'name':route.text,'site':route_name}
        # print('route = ',route.text)
        df = df.append(temp,ignore_index=True)
        
# print(df)        
df['city'] = '北京'
df.to_excel('./subway.xlsx',index=False)
# Out:
# C:\Users\admin\AppData\Roaming\Python\Python36\site-packages\bs4\__init__.py:203: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")

# %% [markdown]
# ### 获取经纬度

# %%
import re

# 获取经度longitude 纬度latitude
def get_location(keyword,city):
    header={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36'}
    request_url = 'http://restapi.amap.com/v3/place/text?key=f839aebd38cd68cc4802c99b45298674&keywords=' + keyword + '&types=&city=' + city + '&children=1&offset=1&page=1&extensions=all'
    data = requests.get(request_url,headers=header)
    data.encoding = 'utf-8'
    data = data.text
    # print(data)
    # "location":"116.337581,39.993138"
    # .*具有贪婪的性质，首先匹配到不能匹配为止
    # 。*？ 则相反，一个匹配以后，就可以继续后面的匹配
    pattern = 'location":"(.*?),(.*?)"'
    # 获取经纬度
    '''
        IndexError                                Traceback (most recent call last)
    <ipython-input-9-dee0fef02142> in <module>
         22 df['longitude'],df['latitude'] = None, None
         23 for index,row in df.iterrows():
    ---> 24     longitude,latitude = get_location(row['name'],row['city'])
         25     df.iloc[index]['longitude'] = longitude
         26     df.iloc[index]['latitude'] = latitude

    <ipython-input-9-dee0fef02142> in get_location(keyword, city)
         15     # 获取经纬度
         16     result = re.findall(pattern,data)
    ---> 17     return result[0][0],result[0][1]
         18 
         19 get_location('五道口站','北京')

    IndexError: list index out of range
    
    此错误是由于高德地图API中没有"石门站" 而是"石门"
    所以下面要加try except
    '''
    result = re.findall(pattern,data)
    try:
        return result[0][0],result[0][1]
    except:
        return get_location(keyword.replace('站',''),city)   

df = pd.read_excel('./subway.xlsx')
df['longitude'],df['latitude'] = None, None
for index,row in df.iterrows():
    longitude,latitude = get_location(row['name'],row['city'])
    df.iloc[index]['longitude'] = longitude
    df.iloc[index]['latitude'] = latitude
    #print(longitude,latitude)

get_location('五道口站','北京')
df.to_excel('./subway.xlsx',index=False)

# %% [markdown]
# ### 进行路径规划

# %%
# 获取数据
data = pd.read_excel('./subway.xlsx')
print(data)
# Out:
#       name    site city   longitude   latitude
# 0      四惠站   地铁八通线   北京  116.498489  39.908279
# 1     四惠东站   地铁八通线   北京  116.514954  39.908051
# 2     高碑店站   地铁八通线   北京  115.858901  39.328727
# 3    传媒大学站   地铁八通线   北京  116.554931  39.909548
# 4      双桥站   地铁八通线   北京  116.569498  39.901066
# ..     ...     ...  ...         ...        ...
# 346    永丰站  地铁16号线   北京  116.237766  40.071247
# 347   永丰南站  地铁16号线   北京  116.247876  40.064807
# 348   西北旺站  地铁16号线   北京  116.258460  40.048344
# 349   马连洼站  地铁16号线   北京  116.274073  40.032358
# 350    西苑站  地铁16号线   北京  116.291136  39.997817
#
# [351 rows x 5 columns]

# %%
from collections import defaultdict

# 计算两点之间的距离
def compute_distance(longitude1,latitude1,longitude2,latitude2):
    header={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36'}
    request_url = 'http://restapi.amap.com/v3/distance?key=f839aebd38cd68cc4802c99b45298674&origins=' + str(longitude1) + ',' + str(latitude1) + '&destination='  + str(longitude2) + ',' + str(latitude2) + '&type=1'
    data = requests.get(request_url,headers=header)
    data.encoding = 'utf-8'
    data = data.text
    # print(data)
    # "distance":"2646","duration":"540"
    pattern = 'distance":"(.*?)","duration":"(.*?)"'
    result = re.findall(pattern,data)
    #print(result[0][0],result[0][1])
    return result[0][0]
    
# 保存途中两点之间的距离
graph = defaultdict(dict)

for i in range(data.shape[0]):
    site1 = data.iloc[i]['site']
    if i < data.shape[0]-1:
        site2 = data.iloc[i+1]['site']
        # 如果是同一条线路
        if site1 == site2:
            longitude1,latitude1 = data.iloc[i]['longitude'],data.iloc[i]['latitude']
            longitude2,latitude2 = data.iloc[i+1]['longitude'],data.iloc[i+1]['latitude']
            name1 = data.iloc[i]['name']
            name2 = data.iloc[i+1]['name'] 
            # 按照距离，计算两点之间距离
            distance = compute_distance(longitude1,latitude1,longitude2,latitude2)
            graph[name1][name2] = distance
            graph[name2][name1] = distance
            print(name1,name2,distance)
            
import pickle
output = open('graph.pkl','wb')
pickle.dump(graph,output)


            
#compute_distance(116.337581,39.993138,116.339941,39.976228)
# Out:
# 四惠站 四惠东站 4143
# 四惠东站 高碑店站 102121
# 高碑店站 传媒大学站 111741
# 传媒大学站 双桥站 4827
# 双桥站 管庄站 3607
# 管庄站 八里桥站 3242
# 八里桥站 通州北苑站 3409
# 通州北苑站 果园站 1472
# 果园站 九棵树站 1510
# 九棵树站 梨园站 2323
# 梨园站 临河里站 2727
# 临河里站 土桥站 1674
# 西二旗站 生命科学园站 6812
# 生命科学园站 朱辛庄站 3479
# 朱辛庄站 巩华城站 6679
# 巩华城站 沙河站 6498
# 沙河站 沙河高教园站 3845
# 沙河高教园站 南邵站 6825
# 南邵站 北邵洼站 1981
# 北邵洼站 昌平东关站 2741
# 昌平东关站 昌平站 9602
# 昌平站 十三陵景区站 9552
# 十三陵景区站 昌平西山口站 2093
# 苏庄站 良乡南关站 2180
# 良乡南关站 良乡大学城西站 2266
# 良乡大学城西站 良乡大学城站 2707
# 良乡大学城站 良乡大学城北站 1514
# 良乡大学城北站 广阳城站 2767
# 广阳城站 篱笆房站 1243
# 篱笆房站 长阳站 2237
# 长阳站 稻田站 4280
# 稻田站 大葆台站 15844
# 大葆台站 郭公庄站 1951
# 宋家庄站 肖村站 3417
# 肖村站 小红门站 2201
# 小红门站 旧宫站 5879
# 旧宫站 亦庄桥站 3397
# 亦庄桥站 亦庄文化园站 2001
# 亦庄文化园站 万源街站 2362
# 万源街站 荣京东街站 1537
# 荣京东街站 荣昌东街站 1465
# 荣昌东街站 同济南路站 2340
# 同济南路站 经海路站 2331
# 经海路站 次渠南站 3275
# 次渠南站 次渠站 2001
# 东直门站 三元桥站 3133
# 三元桥站 三号航站楼站 21939
# 三号航站楼站 二号航站楼站 6395
# 二号航站楼站 三元桥站 19870
# 三元桥站 东直门站 3312
# 苹果园站 古城站 4650
# 古城站 八角游乐园站 3191
# 八角游乐园站 八宝山站 2190
# 八宝山站 玉泉路站 3591
# 玉泉路站 五棵松站 1734
# 五棵松站 万寿路站 2346
# 万寿路站 公主坟站 2217
# 公主坟站 军事博物馆站 825
# 军事博物馆站 木樨地站 4988
# 木樨地站 南礼士路站 2051
# 南礼士路站 复兴门站 1819
# 复兴门站 西单站 4441
# 西单站 天安门西站 5660
# 天安门西站 天安门东站 4825
# 天安门东站 王府井站 2799
# 王府井站 东单站 1095
# 东单站 建国门站 5260
# 建国门站 永安里站 2383
# 永安里站 国贸站 1080
# 国贸站 大望路站 2706
# 大望路站 四惠站 4415
# 四惠站 四惠东站 4143
# 积水潭站 鼓楼大街站 2017
# 鼓楼大街站 安定门站 1661
# 安定门站 雍和宫站 761
# 雍和宫站 东直门站 3117
# 东直门站 东四十条站 1250
# 东四十条站 朝阳门站 1269
# 朝阳门站 建国门站 2344
# 建国门站 北京站 3571
# 北京站 崇文门站 2701
# 崇文门站 前门站 1597
# 前门站 和平门站 1283
# 和平门站 宣武门站 3077
# 宣武门站 长椿街站 1079
# 长椿街站 复兴门站 1186
# 复兴门站 阜成门站 3156
# 阜成门站 车公庄站 2662
# 车公庄站 西直门站 3639
# 西直门站 积水潭站 4054
# 安河桥北站 北宫门站 1954
# 北宫门站 西苑站 2143
# 西苑站 圆明园站 1875
# 圆明园站 北京大学东门站 2537
# 北京大学东门站 中关村站 1502
# 中关村站 海淀黄庄站 891
# 海淀黄庄站 人民大学站 2118
# 人民大学站 魏公村站 3509
# 魏公村站 国家图书馆站 2392
# 国家图书馆站 动物园站 2849
# 动物园站 西直门站 6383
# 西直门站 新街口站 2223
# 新街口站 平安里站 1450
# 平安里站 西四站 985
# 西四站 灵境胡同站 1017
# 灵境胡同站 西单站 2118
# 西单站 宣武门站 1920
# 宣武门站 菜市口站 2825
# 菜市口站 陶然亭站 4029
# 陶然亭站 北京南站 2335
# 北京南站 马家堡站 3469
# 马家堡站 角门西站 2062
# 角门西站 公益西桥站 1405
# 公益西桥站 新宫站 4733
# 新宫站 西红门站 5941
# 西红门站 高米店北站 2760
# 高米店北站 高米店南站 1921
# 高米店南站 枣园站 1976
# 枣园站 清源路站 1515
# 清源路站 黄村西大街站 2101
# 黄村西大街站 黄村火车站 2467
# 黄村火车站 义和庄站 2762
# 义和庄站 生物医药基地站 4101
# 生物医药基地站 天宫院站 2320
# 天通苑北站 天通苑站 834
# 天通苑站 天通苑南站 1092
# 天通苑南站 立水桥站 1503
# 立水桥站 立水桥南站 1224
# 立水桥南站 北苑路北站 1308
# 北苑路北站 大屯路东站 2903
# 大屯路东站 惠新西街北口站 3057
# 惠新西街北口站 惠新西街南口站 1913
# 惠新西街南口站 和平西桥站 3077
# 和平西桥站 和平里北街站 1436
# 和平里北街站 雍和宫站 2880
# 雍和宫站 北新桥站 1435
# 北新桥站 张自忠路站 969
# 张自忠路站 东四站 897
# 东四站 灯市口站 1335
# 灯市口站 东单站 1634
# 东单站 崇文门站 3332
# 崇文门站 磁器口站 2122
# 磁器口站 天坛东门站 2361
# 天坛东门站 蒲黄榆站 2241
# 蒲黄榆站 刘家窑站 2619
# 刘家窑站 宋家庄站 2345
# 海淀五路居站 慈寿寺站 3983
# 慈寿寺站 花园桥站 2641
# 花园桥站 白石桥南站 1814
# 白石桥南站 车公庄西站 2300
# 车公庄西站 车公庄站 1131
# 车公庄站 平安里站 1561
# 平安里站 北海北站 2034
# 北海北站 南锣鼓巷站 2990
# 南锣鼓巷站 东四站 3393
# 东四站 朝阳门站 2514
# 朝阳门站 东大桥站 1969
# 东大桥站 呼家楼站 1059
# 呼家楼站 金台路站 1556
# 金台路站 十里堡站 3310
# 十里堡站 青年路站 2548
# 青年路站 褡裢坡站 5040
# 褡裢坡站 黄渠站 2991
# 黄渠站 常营站 2171
# 常营站 草房站 1386
# 草房站 物资学院路站 3652
# 物资学院路站 通州北关站 4299
# 通州北关站 北运河西站 3645
# 北运河西站 郝家府站 3189
# 郝家府站 东夏园站 1350
# 东夏园站 潞城站 599460
# 北京西站 湾子站 974
# 湾子站 达官营站 959
# 达官营站 广安门内站 1734
# 广安门内站 菜市口站 3136
# 菜市口站 虎坊桥站 2267
# 虎坊桥站 珠市口站 1886
# 珠市口站 桥湾站 1774
# 桥湾站 磁器口站 2040
# 磁器口站 广渠门内站 2177
# 广渠门内站 广渠门外站 2739
# 广渠门外站 九龙山站 241672
# 九龙山站 大郊亭站 238570
# 大郊亭站 百子湾站 5467
# 百子湾站 化工站 2380
# 化工站 南楼梓庄站 1604
# 南楼梓庄站 欢乐谷景区站 1999
# 欢乐谷景区站 双合站 4664
# 双合站 焦化厂站 8482
# 南锣鼓巷站 什刹海站 1177
# 什刹海站 鼓楼大街站 3093
# 鼓楼大街站 安德里北街站 1124
# 安德里北街站 安华桥站 2187
# 安华桥站 北土城站 1963
# 北土城站 奥体中心站 1563
# 奥体中心站 奥林匹克公园站 4571
# 奥林匹克公园站 森林公园南门站 1863
# 森林公园南门站 林萃桥站 3789
# 林萃桥站 永泰庄站 4449
# 永泰庄站 西小口站 1108
# 西小口站 育新站 3082
# 育新站 霍营站 2115
# 霍营站 回龙观东大街站 1113
# 回龙观东大街站 平西府站 2041
# 平西府站 育知路站 2104
# 育知路站 朱辛庄站 2964
# 郭公庄站 丰台科技园站 1568
# 丰台科技园站 科怡路站 3073
# 科怡路站 丰台南路站 1941
# 丰台南路站 丰台东大街站 3650
# 丰台东大街站 七里庄站 1404
# 七里庄站 六里桥站 2067
# 六里桥站 六里桥东站 1311
# 六里桥东站 北京西站 1270
# 北京西站 军事博物馆站 3060
# 军事博物馆站 白堆子站 4016
# 白堆子站 白石桥南站 2793
# 白石桥南站 国家图书馆站 1901
# 车道沟站 长春桥站 1810
# 长春桥站 火器营站 3872
# 火器营站 巴沟站 4159
# 巴沟站 苏州街站 1442
# 苏州街站 海淀黄庄站 1140
# 海淀黄庄站 知春里站 1771
# 知春里站 知春路站 1523
# 知春路站 西土城站 1161
# 西土城站 牡丹园站 5591
# 牡丹园站 健德门站 1869
# 健德门站 北土城站 3094
# 北土城站 安贞门站 975
# 安贞门站 惠新西街南口站 922
# 惠新西街南口站 芍药居站 2871
# 芍药居站 太阳宫站 1294
# 太阳宫站 三元桥站 2493
# 三元桥站 亮马桥站 2160
# 亮马桥站 农业展览馆站 2245
# 农业展览馆站 团结湖站 998
# 团结湖站 呼家楼站 1088
# 呼家楼站 金台夕照站 1984
# 金台夕照站 国贸站 1426
# 国贸站 双井站 4703
# 双井站 劲松站 1771726
# 劲松站 潘家园站 1771661
# 潘家园站 十里河站 2556
# 十里河站 分钟寺站 2743
# 分钟寺站 成寿寺站 3536
# 成寿寺站 宋家庄站 2273
# 宋家庄站 石榴庄站 2257
# 石榴庄站 大红门站 5013
# 大红门站 角门东站 3251
# 角门东站 角门西站 1559
# 角门西站 草桥站 725808
# 草桥站 纪家庙站 732919
# 纪家庙站 首经贸站 2288
# 首经贸站 丰台站 2131
# 丰台站 泥洼站 5241
# 泥洼站 西局站 1834
# 西局站 六里桥站 2752
# 六里桥站 莲花桥站 2867
# 莲花桥站 公主坟站 2826
# 公主坟站 西钓鱼台站 5028
# 西钓鱼台站 慈寿寺站 2099
# 慈寿寺站 车道沟站 6926
# 西直门站 大钟寺站 3403
# 大钟寺站 知春路站 4567
# 知春路站 五道口站 2763
# 五道口站 上地站 7033
# 上地站 西二旗站 2862
# 西二旗站 龙泽站 6892
# 龙泽站 回龙观站 2177
# 回龙观站 霍营站 2474
# 霍营站 立水桥站 7296
# 立水桥站 北苑站 3522
# 北苑站 望京西站 7912
# 望京西站 芍药居站 4675
# 芍药居站 光熙门站 3129
# 光熙门站 柳芳站 2320
# 柳芳站 东直门站 3454
# 张郭庄站 园博园站 2091
# 园博园站 大瓦窑站 6000
# 大瓦窑站 郭庄子站 2610
# 郭庄子站 大井站 6127
# 大井站 七里庄站 3066
# 七里庄站 西局站 1807
# 北京南站 永定门站 3954
# 永定门站 景泰站 1429798
# 景泰站 蒲黄榆站 1458344
# 蒲黄榆站 方庄站 1856
# 方庄站 十里河站 2313
# 十里河站 南八里庄站 10490
# 南八里庄站 北工大西门站 6725
# 北工大西门站 九龙山站 236642
# 九龙山站 大望路站 242078
# 大望路站 红庙站 1159
# 红庙站 金台路站 2112
# 金台路站 朝阳公园站 1486
# 朝阳公园站 枣营站 1826
# 枣营站 东风北桥站 2629
# 东风北桥站 将台站 2890
# 将台站 望京南站 1974
# 望京南站 阜通站 1358
# 阜通站 望京站 1332
# 望京站 东湖渠站 1666
# 东湖渠站 来广营站 2374
# 来广营站 善各庄站 5047
# 清华东路西口站 六道口站 1220
# 六道口站 北沙滩站 2741
# 北沙滩站 奥林匹克公园站 2924
# 奥林匹克公园站 安立路站 2594
# 安立路站 大屯路东站 2037
# 大屯路东站 关庄站 2054
# 关庄站 望京西站 2659
# 望京西站 望京站 2635
# 望京站 望京东站 2161
# 望京东站 崔各庄站 5230
# 崔各庄站 马泉营站 2093
# 马泉营站 孙河站 3553
# 孙河站 国展站 4768
# 国展站 花梨坎站 2504
# 花梨坎站 后沙峪站 5351
# 后沙峪站 南法信站 6585
# 南法信站 石门站 2836
# 石门站 顺义站 1553
# 顺义站 俸伯站 3912
# 北安河站 温阳路站 4510
# 温阳路站 稻香湖站 2270
# 稻香湖站 屯佃站 3038
# 屯佃站 永丰站 6777
# 永丰站 永丰南站 1481
# 永丰南站 西北旺站 2135
# 西北旺站 马连洼站 3386
# 马连洼站 西苑站 4584

# %%
# 读取pickle数据
file = open('graph.pkl','rb')
graph = pickle.load(file)
print(graph)
# Out:
# defaultdict(<class 'dict'>, {'四惠站': {'四惠东站': '4143', '大望路站': '4415'}, '四惠东站': {'四惠站': '4143', '高碑店站': '102121'}, '高碑店站': {'四惠东站': '102121', '传媒大学站': '111741'}, '传媒大学站': {'高碑店站': '111741', '双桥站': '4827'}, '双桥站': {'传媒大学站': '4827', '管庄站': '3607'}, '管庄站': {'双桥站': '3607', '八里桥站': '3242'}, '八里桥站': {'管庄站': '3242', '通州北苑站': '3409'}, '通州北苑站': {'八里桥站': '3409', '果园站': '1472'}, '果园站': {'通州北苑站': '1472', '九棵树站': '1510'}, '九棵树站': {'果园站': '1510', '梨园站': '2323'}, '梨园站': {'九棵树站': '2323', '临河里站': '2727'}, '临河里站': {'梨园站': '2727', '土桥站': '1674'}, '土桥站': {'临河里站': '1674'}, '西二旗站': {'生命科学园站': '6812', '上地站': '2862', '龙泽站': '6892'}, '生命科学园站': {'西二旗站': '6812', '朱辛庄站': '3479'}, '朱辛庄站': {'生命科学园站': '3479', '巩华城站': '6679', '育知路站': '2964'}, '巩华城站': {'朱辛庄站': '6679', '沙河站': '6498'}, '沙河站': {'巩华城站': '6498', '沙河高教园站': '3845'}, '沙河高教园站': {'沙河站': '3845', '南邵站': '6825'}, '南邵站': {'沙河高教园站': '6825', '北邵洼站': '1981'}, '北邵洼站': {'南邵站': '1981', '昌平东关站': '2741'}, '昌平东关站': {'北邵洼站': '2741', '昌平站': '9602'}, '昌平站': {'昌平东关站': '9602', '十三陵景区站': '9552'}, '十三陵景区站': {'昌平站': '9552', '昌平西山口站': '2093'}, '昌平西山口站': {'十三陵景区站': '2093'}, '苏庄站': {'良乡南关站': '2180'}, '良乡南关站': {'苏庄站': '2180', '良乡大学城西站': '2266'}, '良乡大学城西站': {'良乡南关站': '2266', '良乡大学城站': '2707'}, '良乡大学城站': {'良乡大学城西站': '2707', '良乡大学城北站': '1514'}, '良乡大学城北站': {'良乡大学城站': '1514', '广阳城站': '2767'}, '广阳城站': {'良乡大学城北站': '2767', '篱笆房站': '1243'}, '篱笆房站': {'广阳城站': '1243', '长阳站': '2237'}, '长阳站': {'篱笆房站': '2237', '稻田站': '4280'}, '稻田站': {'长阳站': '4280', '大葆台站': '15844'}, '大葆台站': {'稻田站': '15844', '郭公庄站': '1951'}, '郭公庄站': {'大葆台站': '1951', '丰台科技园站': '1568'}, '宋家庄站': {'肖村站': '3417', '刘家窑站': '2345', '成寿寺站': '2273', '石榴庄站': '2257'}, '肖村站': {'宋家庄站': '3417', '小红门站': '2201'}, '小红门站': {'肖村站': '2201', '旧宫站': '5879'}, '旧宫站': {'小红门站': '5879', '亦庄桥站': '3397'}, '亦庄桥站': {'旧宫站': '3397', '亦庄文化园站': '2001'}, '亦庄文化园站': {'亦庄桥站': '2001', '万源街站': '2362'}, '万源街站': {'亦庄文化园站': '2362', '荣京东街站': '1537'}, '荣京东街站': {'万源街站': '1537', '荣昌东街站': '1465'}, '荣昌东街站': {'荣京东街站': '1465', '同济南路站': '2340'}, '同济南路站': {'荣昌东街站': '2340', '经海路站': '2331'}, '经海路站': {'同济南路站': '2331', '次渠南站': '3275'}, '次渠南站': {'经海路站': '3275', '次渠站': '2001'}, '次渠站': {'次渠南站': '2001'}, '东直门站': {'三元桥站': '3312', '雍和宫站': '3117', '东四十条站': '1250', '柳芳站': '3454'}, '三元桥站': {'东直门站': '3312', '三号航站楼站': '21939', '二号航站楼站': '19870', '太阳宫站': '2493', '亮马桥站': '2160'}, '三号航站楼站': {'三元桥站': '21939', '二号航站楼站': '6395'}, '二号航站楼站': {'三号航站楼站': '6395', '三元桥站': '19870'}, '苹果园站': {'古城站': '4650'}, '古城站': {'苹果园站': '4650', '八角游乐园站': '3191'}, '八角游乐园站': {'古城站': '3191', '八宝山站': '2190'}, '八宝山站': {'八角游乐园站': '2190', '玉泉路站': '3591'}, '玉泉路站': {'八宝山站': '3591', '五棵松站': '1734'}, '五棵松站': {'玉泉路站': '1734', '万寿路站': '2346'}, '万寿路站': {'五棵松站': '2346', '公主坟站': '2217'}, '公主坟站': {'万寿路站': '2217', '军事博物馆站': '825', '莲花桥站': '2826', '西钓鱼台站': '5028'}, '军事博物馆站': {'公主坟站': '825', '木樨地站': '4988', '北京西站': '3060', '白堆子站': '4016'}, '木樨地站': {'军事博物馆站': '4988', '南礼士路站': '2051'}, '南礼士路站': {'木樨地站': '2051', '复兴门站': '1819'}, '复兴门站': {'南礼士路站': '1819', '西单站': '4441', '长椿街站': '1186', '阜成门站': '3156'}, '西单站': {'复兴门站': '4441', '天安门西站': '5660', '灵境胡同站': '2118', '宣武门站': '1920'}, '天安门西站': {'西单站': '5660', '天安门东站': '4825'}, '天安门东站': {'天安门西站': '4825', '王府井站': '2799'}, '王府井站': {'天安门东站': '2799', '东单站': '1095'}, '东单站': {'王府井站': '1095', '建国门站': '5260', '灯市口站': '1634', '崇文门站': '3332'}, '建国门站': {'东单站': '5260', '永安里站': '2383', '朝阳门站': '2344', '北京站': '3571'}, '永安里站': {'建国门站': '2383', '国贸站': '1080'}, '国贸站': {'永安里站': '1080', '大望路站': '2706', '金台夕照站': '1426', '双井站': '4703'}, '大望路站': {'国贸站': '2706', '四惠站': '4415', '九龙山站': '242078', '红庙站': '1159'}, '积水潭站': {'鼓楼大街站': '2017', '西直门站': '4054'}, '鼓楼大街站': {'积水潭站': '2017', '安定门站': '1661', '什刹海站': '3093', '安德里北街站': '1124'}, '安定门站': {'鼓楼大街站': '1661', '雍和宫站': '761'}, '雍和宫站': {'安定门站': '761', '东直门站': '3117', '和平里北街站': '2880', '北新桥站': '1435'}, '东四十条站': {'东直门站': '1250', '朝阳门站': '1269'}, '朝阳门站': {'东四十条站': '1269', '建国门站': '2344', '东四站': '2514', '东大桥站': '1969'}, '北京站': {'建国门站': '3571', '崇文门站': '2701'}, '崇文门站': {'北京站': '2701', '前门站': '1597', '东单站': '3332', '磁器口站': '2122'}, '前门站': {'崇文 ...

# %%
# 找到最小开销节点(从U中)
def find_lowest_cost_node(costs):
    #初始化数据
    lowest_cost = float('inf') # 打擂法，初始最小值为正无穷
    lowest_cost_node = None
    # 遍历所有节点
    for node in costs:
        #如果该节点没有被处理
        if not node in processed:
            # 如果当前节点的开销比已经存在的开销小，那么就更新该节点为开销最小节点
            if costs[node] < lowest_cost:
                lowest_cost = costs[node]
                lowest_cost_node = node
    return lowest_cost_node            

# 找到最短路径
def find_shortest_path():
    node = end
    shortest_path = [end]
    # 最终的根节点为start
    while parents[node] != start:
        # 往前移动一步
        node = parents[node]
        # 添加到路径中
        shortest_path.append(node)
    shortest_path.append(start)
        
    return shortest_path

# 计算图中从start到end的最短路径
def dijkstra():
    # 查询到目前开销最小节点
    node = find_lowest_cost_node(costs)
    # print('当前cost最小节点：',node)
    # 使用找到的开销最小的节点，计算它的令居，是否可以通过它进行更新
    # 如果所有的节点都在processed里面，就结束
    while node is not None:
        # 获取节点的cost
        cost = costs[node] # cost是从node到start
        # 获取节点的邻居
        neighbors = graph[node]
        # 遍历所有邻居，看是否可以通过它进行更新
        for neighbor in neighbors.keys():
            # 计算邻居到当前节点 + 当前节点开销
            new_cost = cost + float(neighbors[neighbor])
            if neighbor not in costs or new_cost < costs[neighbor]:
                costs[neighbor] = new_cost
                # 经过node到达neighbor节点，cost更少
                parents[neighbor] = node
        # 将当前节点标记为已处理
        processed.append(node)
        # 下一步，继续找U中最短距离的节点 costs=U,processed=S
        node = find_lowest_cost_node(costs)
        # print('当前cost最小节点：',node)
    
    # 循环完，说明所有节点已经处理完
    shortest_path = find_shortest_path()
    shortest_path.reverse()
    print('从{}到{}的最短路径：{}'.format(start,end,shortest_path))
start = '五道口站'
end = '北京南站'
# 创建节点的开销表，cost是指从start到该节点的距离
costs = {}
# 存储父节点的Hash表，用于记录路径
parents = {} 
parents[end] = None

# 获取节点相邻的节点
#print(graph[start].keys())  dict_keys(['知春路站', '上地站'])
for node in graph[start].keys():
    costs[node] = float(graph[start][node])
    parents[node] = start
#终点到起始点设置为无穷大
costs[end] = float('inf')

# 记录处理过的节点list
processed = []

dijkstra()
# Out:
# 从五道口站到北京南站的最短路径：['五道口站', '知春路站', '大钟寺站', '西直门站', '新街口站', '平安里站', '西四站', '灵境胡同站', '西单站', '宣武门站', '菜市口站', '陶然亭站', '北京南站']

# %%
# %run Route_api.py
# Out:
# ['五道口站', '知春路站', '大钟寺站', '西直门站', '新街口站', '平安里站', '西四站', '灵境胡同站', '西单站', '宣武门站', '菜市口站', '陶然亭站', '北京南站']

# %% [markdown]
# ###  在main.py中需要进行以下设置才可以通过命令行传参的方式运行程序
# #下面这个部分是为了在命令行或者Cell中执行命令 程序可以知道参数要传到哪
#
# import argparse
#
# parser = argparse.ArgumentParser()
#
# parser.add_argument('--site1', type=str, default='清华大学', help='site1')
#
# parser.add_argument('--site2', type=str, default='798', help='site2')
#
# parser.add_argument('--city', type=str, default='北京', help='city')
#
# args = parser.parse_known_args()[0]
#
# site1=args.site1
#
# site2=args.site2
#
# city=args.city

# %%
# %run main.py --site1 清华大学 --site2 798 --city 北京
# Out:
# 清华大学最近的地铁站为五道口站
# 798最近的地铁站为将台站
# 从清华大学 => 798的最短路径为: '清华大学', '五道口站', '知春路站', '西土城站', '牡丹园站', '健德门站', '北土城站', '安贞门站', '惠新西街南口站', '芍药居站', '望京西站', '望京站', '阜通站', '望京南站', '将台站', '798'
