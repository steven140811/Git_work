# %%
import pandas as pd
data = pd.read_csv('./voice.csv')

# %%
data
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
# ...

# %%
#查看缺失值
data.isna().sum()
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
data.shape
# Out:
# (3168, 21)

# %%
print('样本个数：{}'.format(data.shape[0]))
print('男样本个数：{}'.format(data[data.label=='male'].shape[0]))
print('女样本个数：{}'.format(data[data.label=='female'].shape[0]))
# Out:
# 样本个数：3168
# 男样本个数：1584
# 女样本个数：1584

# %%
#分离特征值与lable
X = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
X
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
# ...

# %%
y
# Out:
# 0         male
# 1         male
# 2         male
# 3         male
# 4         male
#          ...
# 3163    female
# 3164    female
# 3165    female
# 3166    female
# 3167    female
# Name: label, Length: 3168, dtype: object

# %%
#使用标签编码
from sklearn.preprocessing import LabelEncoder,StandardScaler
gender_encoder = LabelEncoder()
y = gender_encoder.fit_transform(y)
#对X进行标准化
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %% [markdown]
# ## TPOT中分值最高的方法是ExtraTreesClassifier() 分数为0.9795

# %%
from tpot import TPOTClassifier
tpot = TPOTClassifier(generations=5, population_size=20, verbosity=2)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))
tpot.export('tpot_voice_pipeline.py')
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.9794793834927613
# Generation 2 - Current best internal CV score: 0.9794793834927613
# Generation 3 - Current best internal CV score: 0.9822407247156411
# Generation 4 - Current best internal CV score: 0.9822407247156411
# Generation 5 - Current best internal CV score: 0.9822407247156411
# Best pipeline: ExtraTreesClassifier(PolynomialFeatures(input_matrix, degree=2, include_bias=False, interaction_only=False), bootstrap=False, criterion=entropy, max_features=0.4, min_samples_leaf=5, min_samples_split=2, n_estimators=100)
# 0.9794952681388013

# %% [markdown]
# # SVM中LinearSVC()方法的分数为0.9763

# %%
#SVM
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.svm import LinearSVC
svm = LinearSVC()
svm_fit   = svm.fit(X_train, y_train)
# 模型在测试集上的预测
pred_svm = svm_fit.predict(X_test)
# 模型的准确率
print('SVM模型在测试集的预测准确率：%0.4lf\n' % metrics.accuracy_score(y_test, pred_svm))
# Out:
# SVM模型在测试集的预测准确率：0.9763
# C:\Users\admin\AppData\Roaming\Python\Python36\site-packages\sklearn\svm\_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %% [markdown]
# # Xgboost中XGBClassifier（）方法的分数为0.9811

# %%
#XGBoost
from xgboost import XGBClassifier
# 预设各参数的不同选项值
max_depth = [5,10,15]
learning_rate = [0.1,0.2,0.5]
n_estimators = [50,100,500]
min_child_weight = [2,3,5]
# 将各参数值以字典形式组织起来
parameters = {'max_depth':max_depth, 'learning_rate':learning_rate, 'n_estimators':n_estimators, 
              'min_child_weight':min_child_weight}
# 网格搜索法，测试不同的参数值
grid_dtcateg = GridSearchCV(estimator = XGBClassifier(booster= 'gbtree',random_state=1,objective='binary:logistic'),
                            param_grid = parameters, cv=10)
# 模型拟合
grid_dtcateg.fit(X_train, y_train)
# 返回最佳组合的参数值
grid_dtcateg.best_params_
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 5,
#  'min_child_weight': 3,
#  'n_estimators': 100}

# %%
xgb = XGBClassifier(booster='gbtree',objective='binary:logistic',max_depth=5,learning_rate=0.1,n_estimators=100,min_child_weight=3,
                   random_state=1)
xgb_classifier = xgb.fit(X_train, y_train)
# 模型在测试集上的预测
pred_xgb = xgb_classifier.predict(X_test)
# 模型的准确率
print('XGBoost模型在测试集的预测准确率：%0.4lf\n' % metrics.accuracy_score(y_test, pred_xgb))
# Out:
# XGBoost模型在测试集的预测准确率：0.9811

# %% [markdown]
# # GridSearchCV+Pipeline中RandomForestClassifier（）方法的分数为0.9874

# %%
from sklearn.model_selection import learning_curve, train_test_split,GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
# 构造各种分类器
classifiers = [
    SVC(random_state = 1, kernel = 'rbf'),    
    DecisionTreeClassifier(random_state = 1, criterion = 'gini'),
    RandomForestClassifier(random_state = 1, criterion = 'gini'),
    KNeighborsClassifier(metric = 'minkowski'),
    XGBClassifier(booster='gbtree', random_state=1),
]
# 分类器名称
classifier_names = [
            'svc', 
            'decisiontreeclassifier',
            'randomforestclassifier',
            'kneighborsclassifier',
            'xgboostclassifier',
]
# 分类器参数
classifier_param_grid = [
            {'svc__C':[1], 'svc__gamma':[0.01]},
            {'decisiontreeclassifier__max_depth':[6,9,11]},
            {'randomforestclassifier__n_estimators':[3,5,6]} ,
            {'kneighborsclassifier__n_neighbors':[4,6,8]},
            {'xgboostclassifier__n_estimators':[10,50,100], 'xgboostclassifier__max_depth':[5,7,10]},
]
 
# 对具体的分类器进行GridSearchCV参数调优
def GridSearchCV_work(pipeline, X_train, y_train, X_test, test_y, param_grid, score = 'accuracy'):
    response = {}
    gridsearch = GridSearchCV(estimator = pipeline, param_grid = param_grid, scoring = score)
    # 寻找最优的参数 和最优的准确率分数
    search = gridsearch.fit(X_train, y_train)
    print("GridSearch最优参数：", search.best_params_)
    print("GridSearch最优分数： %0.4lf" %search.best_score_)
    predict_y = gridsearch.predict(X_test)
    print("准确率 %0.4lf" %accuracy_score(y_test, predict_y))
    response['predict_y'] = predict_y
    response['accuracy_score'] = accuracy_score(y_test,predict_y)
    return response
 
for model, model_name, model_param_grid in zip(classifiers, classifier_names, classifier_param_grid):
    pipeline = Pipeline([
            ('scaler', StandardScaler()),
            (model_name, model)
    ])
    result = GridSearchCV_work(pipeline, X_train, y_train, X_test, y_test, model_param_grid , score = 'accuracy')
# Out:
# GridSearch最优参数： {'svc__C': 1, 'svc__gamma': 0.01}
# GridSearch最优分数： 0.9724
# 准确率 0.9826
# GridSearch最优参数： {'decisiontreeclassifier__max_depth': 6}
# GridSearch最优分数： 0.9601
# 准确率 0.9732
# GridSearch最优参数： {'randomforestclassifier__n_estimators': 6}
# GridSearch最优分数： 0.9732
# 准确率 0.9874
# GridSearch最优参数： {'kneighborsclassifier__n_neighbors': 4}
# GridSearch最优分数： 0.9736
# 准确率 0.9748
# GridSearch最优参数： {'xgboostclassifier__max_depth': 7, 'xgboostclassifier__n_estimators': 100}
# GridSearch最优分数： 0.9791
# 准确率 0.9811

# %% [markdown]
# # LGBMClassifier（）方法的分数为0.9858

# %%
from lightgbm import LGBMClassifier
from sklearn.model_selection import cross_val_score, train_test_split, GridSearchCV
from sklearn.metrics import mean_absolute_error,  make_scorer, accuracy_score

# %%
lgb_clf=LGBMClassifier(
                    n_jobs=-1,
                    device_type='cpu',
                    n_estimators=400,
                    learning_rate=0.1,
                    max_depth=16,
                    num_leaves=10,
                    colsample_bytree=0.51,
                    subsample=0.6,
                    random_state=1
                    # max_bins=127,
                )

scores = cross_val_score(lgb_clf, X=X_train, y=y_train, verbose=1, cv = 5, scoring=make_scorer(accuracy_score), n_jobs=-1)
scores.mean()
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    2.0s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.2s finished
# 0.9830304589501914

# %%
import numpy as np
lgb_clf.fit(X_train,y_train)
pred=lgb_clf.predict(X_test)
print('LightGBM模型在测试集的预测准确率：%0.4lf\n' % metrics.accuracy_score(y_test, pred))
# Out:
# LightGBM模型在测试集的预测准确率：0.9858

# %% [markdown]
# # CatBoostClassifier()方法的分数为0.9858

# %%
from catboost import CatBoostClassifier
cat_boost=CatBoostClassifier(iterations=1000, 
                              depth=7, 
                              learning_rate=0.01, 
                              loss_function='Logloss', 
                              eval_metric='AUC',
                              logging_level='Verbose', 
                              metric_period=50,
                              random_state=1
                )
cat_boost.fit(X_train,y_train)
pred_cat=cat_boost.predict(X_test)
print('catboost模型在测试集的预测准确率：%0.4lf\n' % metrics.accuracy_score(y_test, pred_cat))
# Out:
# 0:	total: 9.3ms	remaining: 9.29s
# 50:	total: 352ms	remaining: 6.56s
# 100:	total: 689ms	remaining: 6.13s
# 150:	total: 1.11s	remaining: 6.27s
# 200:	total: 1.5s	remaining: 5.95s
# 250:	total: 1.77s	remaining: 5.29s
# 300:	total: 2.04s	remaining: 4.75s
# 350:	total: 2.32s	remaining: 4.29s
# 400:	total: 2.6s	remaining: 3.88s
# 450:	total: 2.92s	remaining: 3.56s
# 500:	total: 3.21s	remaining: 3.2s
# 550:	total: 3.49s	remaining: 2.85s
# 600:	total: 3.78s	remaining: 2.51s
# 650:	total: 4.18s	remaining: 2.24s
# 700:	total: 4.55s	remaining: 1.94s
# 750:	total: 4.92s	remaining: 1.63s
# 800:	total: 5.21s	remaining: 1.29s
# 850:	total: 5.63s	remaining: 987ms
# 900:	total: 5.97s	remaining: 656ms
# 950:	total: 6.33s	remaining: 326ms
# 999:	total: 6.68s	remaining: 0us
# catboost模型在测试集的预测准确率：0.9858

# %% [markdown]
# # 所以最终评分最高的方法为RandomForestClassifier（）分数为0.9874
