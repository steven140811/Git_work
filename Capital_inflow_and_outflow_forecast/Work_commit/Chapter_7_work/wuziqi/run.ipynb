# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/My Drive/Colab Notebooks/wuziqi/")
# Out:
# Mounted at /content/drive

# %%
# 训练五子棋AI

from __future__ import print_function
import random
import numpy as np
# deque 是一个双端队列
from collections import defaultdict, deque
from game import Board, Game
from mcts_pure import MCTSPlayer as MCTS_Pure # 随机走子策略的AI
from mcts_alphaZero import MCTSPlayer # AlphaGo方式的AI
from policy_value_net_pytorch import PolicyValueNet  # Pytorch

class TrainPipeline():
    def __init__(self, init_model=None):
        # 设置棋盘和游戏的参数
        self.board_width = 6
        self.board_height = 6
        self.n_in_row = 4
        self.board = Board(width=self.board_width,
                           height=self.board_height,
                           n_in_row=self.n_in_row)
        self.game = Game(self.board)
        # 设置训练参数
        self.learn_rate = 2e-3 # 基准学习率
        self.lr_multiplier = 1.0  # 基于KL自动调整学习倍速
        self.temp = 1.0  # 温度参数
        self.n_playout = 400  # 每下一步棋，模拟的步骤数
        self.c_puct = 5 # exploitation和exploration之间的折中系数
        self.buffer_size = 10000
        self.batch_size = 512  # mini-batch size for training
        self.data_buffer = deque(maxlen=self.buffer_size) #使用 deque 创建一个双端队列
        self.play_batch_size = 1
        self.epochs = 5  # num of train_steps for each update
        self.kl_targ = 0.02 # 早停检查
        self.check_freq = 50 # 每50次检查一次，策略价值网络是否更新
        self.game_batch_num = 500 # 训练多少个epoch
        self.best_win_ratio = 0.0 # 当前最佳胜率，用他来判断是否有更好的模型
        # 弱AI（纯MCTS）模拟步数，用于给训练的策略AI提供对手
        self.pure_mcts_playout_num = 1000
        if init_model:
            # 通过init_model设置策略网络
            self.policy_value_net = PolicyValueNet(self.board_width, self.board_height, model_file=init_model)
        else:
            # 训练一个新的策略网络
            self.policy_value_net = PolicyValueNet(self.board_width, self.board_height)
        # AI Player，设置is_selfplay=1 自我对弈，因为是在进行训练
        self.mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                      c_puct=self.c_puct,
                                      n_playout=self.n_playout,
                                      is_selfplay=1)
        
    # 通过旋转和翻转增加数据集, play_data: [(state, mcts_prob, winner_z), ..., ...]
    def get_equi_data(self, play_data):
        extend_data = []
        for state, mcts_porb, winner in play_data:
            # 在4个方向上进行expand，每个方向都进行旋转，水平翻转
            for i in [1, 2, 3, 4]:
                # 逆时针旋转
                equi_state = np.array([np.rot90(s, i) for s in state])
                equi_mcts_prob = np.rot90(np.flipud(mcts_porb.reshape(self.board_height, self.board_width)), i)
                extend_data.append((equi_state, np.flipud(equi_mcts_prob).flatten(), winner))
                # 水平翻转
                equi_state = np.array([np.fliplr(s) for s in equi_state])
                equi_mcts_prob = np.fliplr(equi_mcts_prob)
                extend_data.append((equi_state, np.flipud(equi_mcts_prob).flatten(), winner))
        return extend_data

    # 收集自我对弈数据，用于训练
    def collect_selfplay_data(self, n_games=1):
        for i in range(n_games):
            # 与MCTS Player进行对弈
            winner, play_data = self.game.start_self_play(self.mcts_player, temp=self.temp)
            play_data = list(play_data)[:]
            # 保存下了多少步
            self.episode_len = len(play_data)
            # 增加数据 play_data
            play_data = self.get_equi_data(play_data)
            self.data_buffer.extend(play_data)
            
    # 更新策略网络
    def policy_update(self):
        mini_batch = random.sample(self.data_buffer, self.batch_size)
        state_batch = [data[0] for data in mini_batch]
        mcts_probs_batch = [data[1] for data in mini_batch]
        winner_batch = [data[2] for data in mini_batch]
        # 保存更新前的old_probs, old_v
        old_probs, old_v = self.policy_value_net.policy_value(state_batch)
        for i in range(self.epochs):
            # 每次训练，调整参数，返回loss和entropy
            loss, entropy = self.policy_value_net.train_step(
                    state_batch,
                    mcts_probs_batch,
                    winner_batch,
                    self.learn_rate*self.lr_multiplier)
            # 输入状态，得到行动的可能性和状态值，按照batch进行输入
            new_probs, new_v = self.policy_value_net.policy_value(state_batch)
            # 计算更新前后两次的loss差
            kl = np.mean(np.sum(old_probs * (
                    np.log(old_probs + 1e-10) - np.log(new_probs + 1e-10)),
                    axis=1)
            )
            if kl > self.kl_targ * 4:  # early stopping if D_KL diverges badly
                break
        # 动态调整学习倍率 lr_multiplier
        if kl > self.kl_targ * 2 and self.lr_multiplier > 0.1:
            self.lr_multiplier /= 1.5
        elif kl < self.kl_targ / 2 and self.lr_multiplier < 10:
            self.lr_multiplier *= 1.5

        explained_var_old = (1 -
                             np.var(np.array(winner_batch) - old_v.flatten()) /
                             np.var(np.array(winner_batch)))
        explained_var_new = (1 -
                             np.var(np.array(winner_batch) - new_v.flatten()) /
                             np.var(np.array(winner_batch)))
        print(("kl:{:.5f},"
               "lr_multiplier:{:.3f},"
               "loss:{},"
               "entropy:{},"
               "explained_var_old:{:.3f},"
               "explained_var_new:{:.3f}"
               ).format(kl,
                        self.lr_multiplier,
                        loss,
                        entropy,
                        explained_var_old,
                        explained_var_new))
        return loss, entropy

    # 用于评估训练网络的质量，评估一共10场play，返回比赛胜率（赢1分、输0分、平0.5分）
    def policy_evaluate(self, n_games=10):
        current_mcts_player = MCTSPlayer(self.policy_value_net.policy_value_fn,
                                         c_puct=self.c_puct, n_playout=self.n_playout)
        pure_mcts_player = MCTS_Pure(c_puct=5, n_playout=self.pure_mcts_playout_num)
        win_cnt = defaultdict(int)
        for i in range(n_games):
            # AI和弱AI（纯MCTS）对弈，不需要可视化 is_shown=0，双方轮流职黑 start_player=i % 2
            winner = self.game.start_play(current_mcts_player, pure_mcts_player, start_player=i % 2, is_shown=0)
            win_cnt[winner] += 1
        # 计算胜率，平手计为0.5分
        win_ratio = 1.0*(win_cnt[1] + 0.5*win_cnt[-1]) / n_games
        print("num_playouts:{}, win: {}, lose: {}, tie:{}".format(
                self.pure_mcts_playout_num,
                win_cnt[1], win_cnt[2], win_cnt[-1]))
        return win_ratio

    def run(self):
        # 开始训练
        try:
            # 训练game_batch_num次，每个batch比赛play_batch_size场
            for i in range(self.game_batch_num):
                # 收集自我对弈数据
                self.collect_selfplay_data(self.play_batch_size)
                print("batch i:{}, episode_len:{}".format(i+1, self.episode_len))
                if len(self.data_buffer) > self.batch_size:
                    loss, entropy = self.policy_update()
                # 判断当前模型的表现，保存最优模型
                if (i+1) % self.check_freq == 0:
                    print("current self-play batch: {}".format(i+1))
                    win_ratio = self.policy_evaluate()
                    # 保存当前策略
                    self.policy_value_net.save_model('./current_policy.model')
                    if win_ratio > self.best_win_ratio:
                        print("发现新的最优策略，进行策略更新")
                        self.best_win_ratio = win_ratio
                        # 更新最优策略
                        self.policy_value_net.save_model('./best_policy.model')
                        if (self.best_win_ratio == 1.0 and
                                self.pure_mcts_playout_num < 5000):
                            self.pure_mcts_playout_num += 1000
                            self.best_win_ratio = 0.0
        except KeyboardInterrupt:
            print('\n\rquit')

# %%
if __name__ == '__main__':
    training_pipeline = TrainPipeline()
    training_pipeline.run()
# Out:
# /content/drive/My Drive/Colab Notebooks/wuziqi/policy_value_net_pytorch.py:45: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   x_act = F.log_softmax(self.act_fc1(x_act))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1698: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# batch i:1, episode_len:13
# batch i:2, episode_len:13
# batch i:3, episode_len:15
# batch i:4, episode_len:25
# kl:0.00218,lr_multiplier:1.500,loss:4.451615810394287,entropy:3.5818305015563965,explained_var_old:0.001,explained_var_new:0.216
# batch i:5, episode_len:11
# kl:0.00291,lr_multiplier:2.250,loss:3.642833709716797,entropy:3.5780515670776367,explained_var_old:0.216,explained_var_new:0.991
# batch i:6, episode_len:10
# kl:0.00680,lr_multiplier:3.375,loss:4.287467002868652,entropy:3.5803277492523193,explained_var_old:0.566,explained_var_new:0.544
# batch i:7, episode_len:14
# kl:0.00606,lr_multiplier:5.062,loss:4.55742073059082,entropy:3.566356658935547,explained_var_old:0.025,explained_var_new:0.022
# batch i:8, episode_len:20
# kl:0.00416,lr_multiplier:7.594,loss:5.057908058166504,entropy:3.5777807235717773,explained_var_old:-0.487,explained_var_new:-0.487
# batch i:9, episode_len:20
# kl:0.00348,lr_multiplier:11.391,loss:5.40023946762085,entropy:3.5711259841918945,explained_var_old:-0.832,explained_var_new:-0.832
# batch i:10, episode_len:17
# kl:0.00307,lr_multiplier:11.391,loss:5.7419538497924805,entropy:3.575446844100952,explained_var_old:-0.695,explained_var_new:0.000
# batch i:11, episode_len:17
# kl:0.00200,lr_multiplier:11.391,loss:5.682769775390625,entropy:3.568187952041626,explained_var_old:0.000,explained_var_new:0.000
# batch i:12, episode_len:20
# kl:0.00171,lr_multiplier:11.391,loss:5.785748481750488,entropy:3.564098834991455,explained_var_old:0.000,explained_var_new:0.000
# batch i:13, episode_len:13
# kl:0.00136,lr_multiplier:11.391,loss:5.617917060852051,entropy:3.5635838508605957,explained_var_old:0.000,explained_var_new:0.000
# batch i:14, episode_len:16
# kl:0.00114,lr_multiplier:11.391,loss:5.56799840927124,entropy:3.566188335418701,explained_var_old:0.000,explained_var_new:0.000
# batch i:15, episode_len:15
# kl:0.00065,lr_multiplier:11.391,loss:5.637688636779785,entropy:3.5691754817962646,explained_var_old:0.000,explained_var_new:0.000
# batch i:16, episode_len:23
# kl:0.00083,lr_multiplier:11.391,loss:5.536919116973877,entropy:3.5697407722473145,explained_var_old:0.000,explained_var_new:0.000
# batch i:17, episode_len:12
# kl:0.00078,lr_multiplier:11.391,loss:5.522380828857422,entropy:3.5688250064849854,explained_var_old:0.000,explained_var_new:0.000
# batch i:18, episode_len:13
# kl:0.00066,lr_multiplier:11.391,loss:5.552274227142334,entropy:3.567497730255127,explained_var_old:0.000,explained_var_new:0.000
# batch i:19, episode_len:14
# kl:0.00079,lr_multiplier:11.391,loss:5.653464317321777,entropy:3.566235065460205,explained_var_old:0.000,explained_var_new:0.000
# batch i:20, episode_len:18
# kl:0.00052,lr_multiplier:11.391,loss:5.647932052612305,entropy:3.565791606903076,explained_var_old:0.000,explained_var_new:0.000
# batch i:21, episode_len:7
# kl:0.00117,lr_multiplier:11.391,loss:5.723076820373535,entropy:3.566253423690796,explained_var_old:0.000,explained_var_new:0.000
# batch i:22, episode_len:14
# kl:0.00105,lr_multiplier:11.391,loss:5.6691999435424805,entropy:3.565478801727295,explained_var_old:0.000,explained_var_new:0.000
# batch i:23, episode_len:14
# kl:0.00071,lr_multiplier:11.391,loss:5.663590431213379,entropy:3.5641324520111084,explained_var_old:0.000,explained_var_new:0.000
# batch i:24, episode_len:9
# kl:0.00069,lr_multiplier:11.391,loss:5.600235939025879,entropy:3.5614733695983887,explained_var_old:0.000,explained_var_new:0.000
# batch i:25, episode_len:15
# kl:0.00060,lr_multiplier:11.391,loss:5.691092491149902,entropy:3.5601651668548584,explained_var_old:0.000,explained_var_new:0.000
# batch i:26, episode_len:10
# kl:0.00070,lr_multiplier:11.391,loss:5.635581970214844,entropy:3.5612337589263916,explained_var_old:0.000,explained_var_new:0.000
# batch i:27, episode_len:16
# kl:0.00085,lr_multiplier:11.391,loss:5.723062038421631,entropy:3.563056468963623,explained_var_old:0.000,explained_var_new:0.000
# batch i:28, episode_len:9
# kl:0.00073,lr_multiplier:11.391,loss:5.603983402252197,entropy:3.564636468887329,explained_var_old:0.000,explained_var_new:0.000
# batch i:29, episode_len:17
# kl:0.00078,lr_multiplier:11.391,loss:5.614171028137207,entropy:3.5641894340515137,explained_var_old:0.000,explained_var_new:0.000
# batch i:30, episode_len:14
# kl:0.00062,lr_multiplier:11.391,loss:5.689245223999023,entropy:3.5618250370025635,explained_var_old:0.000,explained_var_new:0.000
# batch i:31, episode_len:15
# kl:0.00065,lr_multiplier:11.391,loss:5.735410213470459,entropy:3.5625529289245605,explained_var_old:0.000,explained_var_new:0.000
# batch i:32, episode_len:17
# kl:0.00093,lr_multiplier:11.391,loss:5.496644973754883,entropy:3.5652661323547363,explained_var_old:0.000,explained_var_new:0.000
# batch i:33, episode_len:13
# kl:0.00080,lr_multiplier:11.391,loss:5.585592269897461,entropy:3.5671656131744385,explained_var_old:0.000,explained_var_new:0.000
# batch i:34, episode_len:18
# kl:0.00063,lr_multiplier:11.391,loss:5.621872425079346,entropy:3.5679593086242676,explained_var_old:0.000,explained_var_new:0.000
# batch i:35, episode_len:23
# kl:0.00082,lr_multiplier:11.391,loss:5.6327104568481445,entropy:3.5681538581848145,explained_var_old:0.000,explained_var_new:0.000
# batch i:36, episode_len:17
# kl:0.00078,lr_multiplier:11.391,loss:5.5340399742126465,entropy:3.5674166679382324,explained_var_old:0.000,explained_var_new:0.000
# batch i:37, episode_len:11
# kl:0.00082,lr_multiplier:11.391,loss:5.737330436706543,entropy:3.5654032230377197,explained_var_old:0.000,explained_var_new:0.000
# batch i:38, episode_len:15
# kl:0.00069,lr_multiplier:11.391,loss:5.638854026794434,entropy:3.564063787460327,explained_var_old:0.000,explained_var_new:0.000
# batch i:39, episode_len:17
# kl:0.00086,lr_multiplier:11.391,loss:5.837499141693115,entropy:3.5635793209075928,explained_var_old:0.000,explained_var_new:0.000
# batch i:40, episode_len:15
# kl:0.00083,lr_multiplier:11.391,loss:5.655465126037598,entropy:3.563537836074829,explained_var_old:0.000,explained_var_new:0.000
# batch i:41, episode_len:12
# kl:0.00097,lr_multiplier:11.391,loss:5.689297676086426,entropy:3.564319372177124,explained_var_old:0.000,explained_var_new:0.000
# batch i:42, episode_len:19
# kl:0.00092,lr_multiplier:11.391,loss:5.711062908172607,entropy:3.565300464630127,explained_var_old:0.000,explained_var_new:0.000
# batch i:43, episode_len:22
# kl:0.00089,lr_multiplier:11.391,loss:5.455235481262207,entropy:3.566131830215454,explained_var_old:0.000,explained_var_new:0.000
# batch i:44, episode_len:15
# kl:0.00082,lr_multiplier:11.391,loss:5.602240562438965,entropy:3.564659595489502,explained_var_old:0.000,explained_var_new:0.000
# batch i:45, episode_len:11
# kl:0.00072,lr_multiplier:11.391,loss:5.682387351989746,entropy:3.5626447200775146,explained_var_old:0.000,explained_var_new:0.000
# batch i:46, episode_len:18
# kl:0.00082,lr_multiplier:11.391,loss:5.691980361938477,entropy:3.5638010501861572,explained_var_old:0.000,explained_var_new:0.000
# batch i:47, episode_len:9
# kl:0.00098,lr_multiplier:11.391,loss:5.659972667694092,entropy:3.5665059089660645,explained_var_old:0.000,explained_var_new:0.000
# batch i:48, episode_len:9
# kl:0.00083,lr_multiplier:11.391,loss:5.659145355224609,entropy:3.5671801567077637,explained_var_old:0.000,explained_var_new:0.000
# batch i:49, episode_len:13
# kl:0.00079,lr_multiplier:11.391,loss:5.592065334320068,entropy:3.566704034805298,explained_var_old:0.000,explained_var_new:0.000
# batch i:50, episode_len:11
# kl:0.00065,lr_multiplier:11.391,loss:5.613944053649902,entropy:3.566291332244873,explained_var_old:0.000,explained_var_new:0.000
# current self-play batch: 50
# num_playouts:1000, win: 1, lose: 9, tie:0
# 发现新的最优策略，进行策略更新
# batch i:51, episode_len:17
# kl:0.00105,lr_multiplier:11.391,loss:5.698851108551025,entropy:3.565330982208252,explained_var_old:0.000,explained_var_new:0.000
# batch i:52, episode_len:19
# kl:0.00100,lr_multiplier:11.391,loss:5.537508964538574,entropy:3.5645065307617188,explained_var_old:0.000,explained_var_new:0.000
# batch i:53, episode_len:17
# kl:0.00071,lr_multiplier:11.391,loss:5.7866668701171875,entropy:3.5645713806152344,explained_var_old:0.000,explained_var_new:0.000
# batch i:54, episode_len:10
# kl:0.00080,lr_multiplier:11.391,loss:5.529527187347412,entropy:3.565624475479126,explained_var_old:0.000,explained_var_new:0.000
# batch i:55, episode_len:14
# kl:0.00076,lr_multiplier:11.391,loss:5.738134384155273,entropy:3.566563129425049,explained_var_old:0.000,explained_var_new:0.000
# batch i:56, episode_len:12
# kl:0.00081,lr_multiplier:11.391,loss:5.542944431304932,entropy:3.5661776065826416,explained_var_old:0.000,explained_var_new:0.000
# batch i:57, episode_len:9
# kl:0.00074,lr_multiplier:11.391,loss:5.523934841156006,entropy:3.5645596981048584,explained_var_old:0.000,explained_var_new:0.000
# batch i:58, episode_len:14
# kl:0.00070,lr_multiplier:11.391,loss:5.6392621994018555,entropy:3.5619351863861084,explained_var_old:0.000,explained_var_new:0.000
# batch i:59, episode_len:12
# kl:0.00099,lr_multiplier:11.391,loss:5.773941516876221,entropy:3.5612406730651855,explained_var_old:0.000,explained_var_new:0.000
# batch i:60, episode_len:12
# kl:0.00088,lr_multiplier:11.391,loss:5.679716110229492,entropy:3.563812732696533,explained_var_old:0.000,explained_var_new:0.000
# batch i:61, episode_len:36
# kl:0.00103,lr_multiplier:11.391,loss:5.637250900268555,entropy:3.566906213760376,explained_var_old:0.000,explained_var_new:0.000
# batch i:62, episode_len:18
# kl:0.00087,lr_multiplier:11.391,loss:5.505927085876465,entropy:3.5690951347351074,explained_var_old:0.000,explained_var_new:0.000
# batch i:63, episode_len:18
# kl:0.00075,lr_multiplier:11.391,loss:5.6978631019592285,entropy:3.5699925422668457,explained_var_old:0.000,explained_var_new:0.000
# batch i:64, episode_len:14
# kl:0.00082,lr_multiplier:11.391,loss:5.577243804931641,entropy:3.569251537322998,explained_var_old:0.000,explained_var_new:0.000
# batch i:65, episode_len:18
# kl:0.00111,lr_multiplier:11.391,loss:5.565910339355469,entropy:3.5676915645599365,explained_var_old:0.000,explained_var_new:0.000
# batch i:66, episode_len:17
# kl:0.00081,lr_multiplier:11.391,loss:5.565530776977539,entropy:3.566406011581421,explained_var_old:0.000,explained_var_new:0.000
# batch i:67, episode_len:11
# kl:0.00098,lr_multiplier:11.391,loss:5.792376518249512,entropy:3.566192865371704,explained_var_old:0.000,explained_var_new:0.000
# batch i:68, episode_len:22
# kl:0.00080,lr_multiplier:11.391,loss:5.542151927947998,entropy:3.5656473636627197,explained_var_old:0.000,explained_var_new:0.000
# batch i:69, episode_len:13
# kl:0.00091,lr_multiplier:11.391,loss:5.664309501647949,entropy:3.5650668144226074,explained_var_old:0.000,explained_var_new:0.000
# batch i:70, episode_len:17
# kl:0.00069,lr_multiplier:11.391,loss:5.560401916503906,entropy:3.5642125606536865,explained_var_old:0.000,explained_var_new:0.000
# batch i:71, episode_len:9
# kl:0.00058,lr_multiplier:11.391,loss:5.632270812988281,entropy:3.5633387565612793,explained_var_old:0.000,explained_var_new:0.000
# batch i:72, episode_len:15
# kl:0.00059,lr_multiplier:11.391,loss:5.7218146324157715,entropy:3.5636746883392334,explained_var_old:0.000,explained_var_new:0.000
# batch i:73, episode_len:17
# kl:0.00074,lr_multiplier:11.391,loss:5.670596122741699,entropy:3.565498113632202,explained_var_old:0.000,explained_var_new:0.000
# batch i:74, episode_len:16
# kl:0.00096,lr_multiplier:11.391,loss:5.507457733154297,entropy:3.567523717880249,explained_var_old:0.000,explained_var_new:0.000
# batch i:75, episode_len:20
# kl:0.00115,lr_multiplier:11.391,loss:5.594147682189941,entropy:3.567657232284546,explained_var_old:0.000,explained_var_new:0.000
# batch i:76, episode_len:21
# kl:0.00086,lr_multiplier:11.391,loss:5.572049140930176,entropy:3.567314624786377,explained_var_old:0.000,explained_var_new:0.000
# batch i:77, episode_len:10
# kl:0.00082,lr_multiplier:11.391,loss:5.537014007568359,entropy:3.567718267440796,explained_var_old:0.000,explained_var_new:0.000
# batch i:78, episode_len:19
# kl:0.00096,lr_multiplier:11.391,loss:5.653790473937988,entropy:3.5678555965423584,explained_var_old:0.000,explained_var_new:0.000
# batch i:79, episode_len:7
# kl:0.00086,lr_multiplier:11.391,loss:5.6793742179870605,entropy:3.566845178604126,explained_var_old:0.000,explained_var_new:0.000
# batch i:80, episode_len:16
# kl:0.00047,lr_multiplier:11.391,loss:5.667003631591797,entropy:3.566192626953125,explained_var_old:0.000,explained_var_new:0.000
# batch i:81, episode_len:17
# kl:0.00078,lr_multiplier:11.391,loss:5.665890693664551,entropy:3.5653111934661865,explained_var_old:0.000,explained_var_new:0.000
# batch i:82, episode_len:18
# kl:0.00085,lr_multiplier:11.391,loss:5.607334613800049,entropy:3.5654454231262207,explained_var_old:0.000,explained_var_new:0.000
# batch i:83, episode_len:9
# kl:0.00060,lr_multiplier:11.391,loss:5.599486351013184,entropy:3.566791296005249,explained_var_old:0.000,explained_var_new:0.000
# batch i:84, episode_len:24
# kl:0.00099,lr_multiplier:11.391,loss:5.5789971351623535,entropy:3.565342664718628,explained_var_old:0.000,explained_var_new:0.000
# batch i:85, episode_len:20
# kl:0.00076,lr_multiplier:11.391,loss:5.6406426429748535,entropy:3.5616343021392822,explained_var_old:0.000,explained_var_new:0.000
# batch i:86, episode_len:16
# kl:0.00075,lr_multiplier:11.391,loss:5.585064888000488,entropy:3.5598673820495605,explained_var_old:0.000,explained_var_new:0.000
# batch i:87, episode_len:14
# kl:0.00120,lr_multiplier:11.391,loss:5.660188674926758,entropy:3.5623247623443604,explained_var_old:0.000,explained_var_new:0.000
# batch i:88, episode_len:15
# kl:0.00090,lr_multiplier:11.391,loss:5.774748802185059,entropy:3.565186023712158,explained_var_old:0.000,explained_var_new:0.000
# batch i:89, episode_len:20
# kl:0.00080,lr_multiplier:11.391,loss:5.750373840332031,entropy:3.5653765201568604,explained_var_old:0.000,explained_var_new:0.000
# batch i:90, episode_len:13
# kl:0.00083,lr_multiplier:11.391,loss:5.655688285827637,entropy:3.564518451690674,explained_var_old:0.000,explained_var_new:0.000
# batch i:91, episode_len:9
# kl:0.00071,lr_multiplier:11.391,loss:5.639082908630371,entropy:3.56449556350708,explained_var_old:0.000,explained_var_new:0.000
# batch i:92, episode_len:11
# kl:0.00059,lr_multiplier:11.391,loss:5.602039337158203,entropy:3.5647006034851074,explained_var_old:0.000,explained_var_new:0.000
# batch i:93, episode_len:19
# kl:0.00081,lr_multiplier:11.391,loss:5.689537525177002,entropy:3.5633091926574707,explained_var_old:0.000,explained_var_new:0.000
# batch i:94, episode_len:9
# kl:0.00089,lr_multiplier:11.391,loss:5.4126081466674805,entropy:3.561217784881592,explained_var_old:0.000,explained_var_new:0.000
# batch i:95, episode_len:9
# kl:0.00103,lr_multiplier:11.391,loss:5.692683219909668,entropy:3.5595552921295166,explained_var_old:0.000,explained_var_new:0.000
# batch i:96, episode_len:11
# kl:0.00086,lr_multiplier:11.391,loss:5.699871063232422,entropy:3.5596842765808105,explained_var_old:0.000,explained_var_new:0.000
# batch i:97, episode_len:23
# kl:0.00145,lr_multiplier:11.391,loss:5.628074645996094,entropy:3.561950206756592,explained_var_old:0.000,explained_var_new:0.000
# batch i:98, episode_len:23
# kl:0.00114,lr_multiplier:11.391,loss:5.603994846343994,entropy:3.563271999359131,explained_var_old:0.000,explained_var_new:0.000
# batch i:99, episode_len:15
# kl:6.02271,lr_multiplier:7.594,loss:5.572746276855469,entropy:3.5632128715515137,explained_var_old:0.000,explained_var_new:0.000
# batch i:100, episode_len:20
# kl:1.74851,lr_multiplier:5.062,loss:11.480113983154297,entropy:1.7466089725494385,explained_var_old:0.000,explained_var_new:-0.000
# current self-play batch: 100
# num_playouts:1000, win: 1, lose: 9, tie:0
# batch i:101, episode_len:14
# kl:0.00055,lr_multiplier:7.594,loss:5.251108646392822,entropy:3.5650901794433594,explained_var_old:-0.000,explained_var_new:-0.261
# batch i:102, episode_len:13
# kl:0.38894,lr_multiplier:5.062,loss:5.296182632446289,entropy:3.551313638687134,explained_var_old:-0.284,explained_var_new:0.000
# batch i:103, episode_len:9
# kl:0.23313,lr_multiplier:3.375,loss:4.946877479553223,entropy:3.3099498748779297,explained_var_old:0.000,explained_var_new:0.000
# batch i:104, episode_len:12
# kl:0.00013,lr_multiplier:5.062,loss:4.526330947875977,entropy:3.567322015762329,explained_var_old:0.000,explained_var_new:0.000
# batch i:105, episode_len:7
# kl:0.00031,lr_multiplier:7.594,loss:4.5424675941467285,entropy:3.568114995956421,explained_var_old:0.000,explained_var_new:0.000
# batch i:106, episode_len:16
# kl:0.00063,lr_multiplier:11.391,loss:4.544451713562012,entropy:3.5681231021881104,explained_var_old:0.000,explained_var_new:0.000
# batch i:107, episode_len:10
# kl:0.00091,lr_multiplier:11.391,loss:4.5325236320495605,entropy:3.5663607120513916,explained_var_old:0.000,explained_var_new:0.000
# batch i:108, episode_len:10
# kl:0.00076,lr_multiplier:11.391,loss:4.534095764160156,entropy:3.5646514892578125,explained_var_old:0.000,explained_var_new:0.000
# batch i:109, episode_len:12
# kl:0.00054,lr_multiplier:11.391,loss:4.537528038024902,entropy:3.564861536026001,explained_var_old:0.000,explained_var_new:0.000
# batch i:110, episode_len:16
# kl:0.00086,lr_multiplier:11.391,loss:4.536942005157471,entropy:3.5663721561431885,explained_var_old:0.000,explained_var_new:0.000
# batch i:111, episode_len:13
# kl:0.00084,lr_multiplier:11.391,loss:4.532798767089844,entropy:3.5667800903320312,explained_var_old:0.000,explained_var_new:0.000
# batch i:112, episode_len:24
# kl:0.00041,lr_multiplier:11.391,loss:4.541223526000977,entropy:3.5671842098236084,explained_var_old:0.000,explained_var_new:0.000
# batch i:113, episode_len:15
# kl:0.00064,lr_multiplier:11.391,loss:4.533254623413086,entropy:3.5684895515441895,explained_var_old:0.000,explained_var_new:0.000
# batch i:114, episode_len:20
# kl:0.00054,lr_multiplier:11.391,loss:4.530438423156738,entropy:3.5681042671203613,explained_var_old:0.000,explained_var_new:0.000
# batch i:115, episode_len:18
# kl:0.00051,lr_multiplier:11.391,loss:4.548260688781738,entropy:3.5663723945617676,explained_var_old:0.000,explained_var_new:0.000
# batch i:116, episode_len:14
# kl:0.00070,lr_multiplier:11.391,loss:4.523292064666748,entropy:3.5645105838775635,explained_var_old:0.000,explained_var_new:0.000
# batch i:117, episode_len:16
# kl:0.00055,lr_multiplier:11.391,loss:4.530758857727051,entropy:3.5622098445892334,explained_var_old:0.000,explained_var_new:0.000
# batch i:118, episode_len:13
# kl:0.00040,lr_multiplier:11.391,loss:4.535340309143066,entropy:3.5615732669830322,explained_var_old:0.000,explained_var_new:0.000
# batch i:119, episode_len:9
# kl:0.00063,lr_multiplier:11.391,loss:4.540440559387207,entropy:3.5640482902526855,explained_var_old:0.000,explained_var_new:0.000
# batch i:120, episode_len:18
# kl:0.00062,lr_multiplier:11.391,loss:4.53021240234375,entropy:3.566254138946533,explained_var_old:0.000,explained_var_new:0.000
# batch i:121, episode_len:11
# kl:0.00053,lr_multiplier:11.391,loss:4.529450416564941,entropy:3.5668187141418457,explained_var_old:0.000,explained_var_new:0.000
# batch i:122, episode_len:11
# kl:0.00072,lr_multiplier:11.391,loss:4.553775787353516,entropy:3.5668721199035645,explained_var_old:0.000,explained_var_new:0.000
# batch i:123, episode_len:9
# kl:0.00030,lr_multiplier:11.391,loss:4.545465469360352,entropy:3.566131353378296,explained_var_old:0.000,explained_var_new:0.000
# batch i:124, episode_len:13
# kl:0.00032,lr_multiplier:11.391,loss:4.541083335876465,entropy:3.5654032230377197,explained_var_old:0.000,explained_var_new:0.000
# batch i:125, episode_len:12
# kl:0.00065,lr_multiplier:11.391,loss:4.540652275085449,entropy:3.564152240753174,explained_var_old:0.000,explained_var_new:0.000
# batch i:126, episode_len:12
# kl:0.00054,lr_multiplier:11.391,loss:4.536774158477783,entropy:3.561286449432373,explained_var_old:0.000,explained_var_new:0.000
# batch i:127, episode_len:23
# kl:0.00037,lr_multiplier:11.391,loss:4.539463996887207,entropy:3.559837579727173,explained_var_old:0.000,explained_var_new:0.000
# batch i:128, episode_len:19
# kl:0.00077,lr_multiplier:11.391,loss:4.543965816497803,entropy:3.5616910457611084,explained_var_old:0.000,explained_var_new:0.000
# batch i:129, episode_len:17
# kl:0.00089,lr_multiplier:11.391,loss:4.535425662994385,entropy:3.5644989013671875,explained_var_old:0.000,explained_var_new:0.000
# batch i:130, episode_len:14
# kl:0.00047,lr_multiplier:11.391,loss:4.535441875457764,entropy:3.5664827823638916,explained_var_old:0.000,explained_var_new:0.000
# batch i:131, episode_len:17
# kl:0.00078,lr_multiplier:11.391,loss:4.533755302429199,entropy:3.566680669784546,explained_var_old:0.000,explained_var_new:0.000
# batch i:132, episode_len:15
# kl:0.00079,lr_multiplier:11.391,loss:4.545434474945068,entropy:3.5645787715911865,explained_var_old:0.000,explained_var_new:0.000
# batch i:133, episode_len:20
# kl:0.00061,lr_multiplier:11.391,loss:4.525246620178223,entropy:3.561919689178467,explained_var_old:0.000,explained_var_new:0.000
# batch i:134, episode_len:14
# kl:0.00038,lr_multiplier:11.391,loss:4.524307727813721,entropy:3.5605008602142334,explained_var_old:0.000,explained_var_new:0.000
# batch i:135, episode_len:18
# kl:0.00021,lr_multiplier:11.391,loss:4.529994010925293,entropy:3.560218572616577,explained_var_old:0.000,explained_var_new:0.000
# batch i:136, episode_len:18
# kl:0.00047,lr_multiplier:11.391,loss:4.535264492034912,entropy:3.5609853267669678,explained_var_old:0.000,explained_var_new:0.000
# batch i:137, episode_len:16
# kl:0.00044,lr_multiplier:11.391,loss:4.5179314613342285,entropy:3.561755895614624,explained_var_old:0.000,explained_var_new:0.000
# batch i:138, episode_len:13
# kl:0.00039,lr_multiplier:11.391,loss:4.546171188354492,entropy:3.5613865852355957,explained_var_old:0.000,explained_var_new:0.000
# batch i:139, episode_len:25
# kl:0.00056,lr_multiplier:11.391,loss:4.5284013748168945,entropy:3.5600085258483887,explained_var_old:0.000,explained_var_new:0.000
# batch i:140, episode_len:13
# kl:0.00059,lr_multiplier:11.391,loss:4.534574508666992,entropy:3.5593984127044678,explained_var_old:0.000,explained_var_new:0.000
# batch i:141, episode_len:14
# kl:0.00077,lr_multiplier:11.391,loss:4.542048931121826,entropy:3.56013822555542,explained_var_old:0.000,explained_var_new:0.000
# batch i:142, episode_len:17
# kl:0.00070,lr_multiplier:11.391,loss:4.537984371185303,entropy:3.56154203414917,explained_var_old:0.000,explained_var_new:0.000
# batch i:143, episode_len:23
# kl:0.00049,lr_multiplier:11.391,loss:4.576503276824951,entropy:3.5621190071105957,explained_var_old:0.000,explained_var_new:0.000
# batch i:144, episode_len:14
# kl:0.00053,lr_multiplier:11.391,loss:4.562180519104004,entropy:3.562138080596924,explained_var_old:0.000,explained_var_new:0.000
# batch i:145, episode_len:23
# kl:0.00054,lr_multiplier:11.391,loss:4.5679450035095215,entropy:3.5620579719543457,explained_var_old:0.000,explained_var_new:0.000
# batch i:146, episode_len:14
# kl:0.00045,lr_multiplier:11.391,loss:4.567942142486572,entropy:3.5633959770202637,explained_var_old:0.000,explained_var_new:0.000
# batch i:147, episode_len:18
# kl:0.00075,lr_multiplier:11.391,loss:4.557187080383301,entropy:3.5647122859954834,explained_var_old:0.000,explained_var_new:0.000
# batch i:148, episode_len:24
# kl:0.00081,lr_multiplier:11.391,loss:4.558504581451416,entropy:3.5630953311920166,explained_var_old:0.000,explained_var_new:0.000
# batch i:149, episode_len:17
# kl:0.00054,lr_multiplier:11.391,loss:4.558653831481934,entropy:3.5591773986816406,explained_var_old:0.000,explained_var_new:0.000
# batch i:150, episode_len:13
# kl:0.00066,lr_multiplier:11.391,loss:4.559693336486816,entropy:3.5572433471679688,explained_var_old:0.000,explained_var_new:0.000
# current self-play batch: 150
# num_playouts:1000, win: 3, lose: 7, tie:0
# 发现新的最优策略，进行策略更新
# batch i:151, episode_len:17
# kl:0.00083,lr_multiplier:11.391,loss:4.550211429595947,entropy:3.5580215454101562,explained_var_old:0.000,explained_var_new:0.000
# batch i:152, episode_len:15
# kl:0.00069,lr_multiplier:11.391,loss:4.566699028015137,entropy:3.5600504875183105,explained_var_old:0.000,explained_var_new:0.000
# batch i:153, episode_len:12
# kl:0.00072,lr_multiplier:11.391,loss:4.566522598266602,entropy:3.561957836151123,explained_var_old:0.000,explained_var_new:0.000
# batch i:154, episode_len:13
# kl:0.00089,lr_multiplier:11.391,loss:4.562033653259277,entropy:3.56235933303833,explained_var_old:0.000,explained_var_new:0.000
# batch i:155, episode_len:11
# kl:0.00084,lr_multiplier:11.391,loss:4.568552494049072,entropy:3.562603235244751,explained_var_old:0.000,explained_var_new:0.000
# batch i:156, episode_len:17
# kl:0.00062,lr_multiplier:11.391,loss:4.556751728057861,entropy:3.5631566047668457,explained_var_old:0.000,explained_var_new:0.000
# batch i:157, episode_len:11
# kl:0.00060,lr_multiplier:11.391,loss:4.559876441955566,entropy:3.5633199214935303,explained_var_old:0.000,explained_var_new:0.000
# batch i:158, episode_len:17
# kl:0.00070,lr_multiplier:11.391,loss:4.564060211181641,entropy:3.5619359016418457,explained_var_old:0.000,explained_var_new:0.000
# batch i:159, episode_len:12
# kl:0.00094,lr_multiplier:11.391,loss:4.555761814117432,entropy:3.5590548515319824,explained_var_old:0.000,explained_var_new:0.000
# batch i:160, episode_len:16
# kl:0.00052,lr_multiplier:11.391,loss:4.568863868713379,entropy:3.556373119354248,explained_var_old:0.000,explained_var_new:0.000
# batch i:161, episode_len:29
# kl:0.00067,lr_multiplier:11.391,loss:4.561641693115234,entropy:3.5569264888763428,explained_var_old:0.000,explained_var_new:0.000
# batch i:162, episode_len:36
# kl:0.00094,lr_multiplier:11.391,loss:4.540962219238281,entropy:3.5579488277435303,explained_var_old:0.000,explained_var_new:0.000
# batch i:163, episode_len:20
# kl:0.00078,lr_multiplier:11.391,loss:4.53326416015625,entropy:3.5585215091705322,explained_var_old:0.000,explained_var_new:0.000
# batch i:164, episode_len:15
# kl:0.00078,lr_multiplier:11.391,loss:4.516239166259766,entropy:3.5602266788482666,explained_var_old:0.000,explained_var_new:0.000
# batch i:165, episode_len:13
# kl:0.00058,lr_multiplier:11.391,loss:4.534629821777344,entropy:3.5619235038757324,explained_var_old:0.000,explained_var_new:0.000
# batch i:166, episode_len:12
# kl:0.00070,lr_multiplier:11.391,loss:4.52314567565918,entropy:3.563483953475952,explained_var_old:0.000,explained_var_new:0.000
# batch i:167, episode_len:10
# kl:0.00061,lr_multiplier:11.391,loss:4.525561809539795,entropy:3.5623512268066406,explained_var_old:0.000,explained_var_new:0.000
# batch i:168, episode_len:12
# kl:0.00082,lr_multiplier:11.391,loss:4.525676727294922,entropy:3.5590856075286865,explained_var_old:0.000,explained_var_new:0.000
# batch i:169, episode_len:19
# kl:0.00093,lr_multiplier:11.391,loss:4.532148838043213,entropy:3.5562517642974854,explained_var_old:0.000,explained_var_new:0.000
# batch i:170, episode_len:20
# kl:0.00081,lr_multiplier:11.391,loss:4.498314380645752,entropy:3.5562021732330322,explained_var_old:0.000,explained_var_new:0.000
# batch i:171, episode_len:20
# kl:0.00086,lr_multiplier:11.391,loss:4.535578727722168,entropy:3.5572850704193115,explained_var_old:0.000,explained_var_new:0.000
# batch i:172, episode_len:15
# kl:0.00078,lr_multiplier:11.391,loss:4.541733264923096,entropy:3.559253454208374,explained_var_old:0.000,explained_var_new:0.000
# batch i:173, episode_len:15
# kl:0.00091,lr_multiplier:11.391,loss:4.534991264343262,entropy:3.5624887943267822,explained_var_old:0.000,explained_var_new:0.000
# batch i:174, episode_len:16
# kl:0.00113,lr_multiplier:11.391,loss:4.534331321716309,entropy:3.5638697147369385,explained_var_old:0.000,explained_var_new:0.000
# batch i:175, episode_len:8
# kl:0.00084,lr_multiplier:11.391,loss:4.5245466232299805,entropy:3.5634307861328125,explained_var_old:0.000,explained_var_new:0.000
# batch i:176, episode_len:13
# kl:0.00076,lr_multiplier:11.391,loss:4.545592308044434,entropy:3.563133716583252,explained_var_old:0.000,explained_var_new:0.000
# batch i:177, episode_len:19
# kl:0.00076,lr_multiplier:11.391,loss:4.5185465812683105,entropy:3.561755895614624,explained_var_old:0.000,explained_var_new:0.000
# batch i:178, episode_len:12
# kl:0.00074,lr_multiplier:11.391,loss:4.5452165603637695,entropy:3.5605547428131104,explained_var_old:0.000,explained_var_new:0.000
# batch i:179, episode_len:19
# kl:0.00088,lr_multiplier:11.391,loss:4.526464939117432,entropy:3.560822010040283,explained_var_old:0.000,explained_var_new:0.000
# batch i:180, episode_len:21
# kl:0.00055,lr_multiplier:11.391,loss:4.532919883728027,entropy:3.561302661895752,explained_var_old:0.000,explained_var_new:0.000
# batch i:181, episode_len:10
# kl:0.00073,lr_multiplier:11.391,loss:4.543779373168945,entropy:3.5619969367980957,explained_var_old:0.000,explained_var_new:0.000
# batch i:182, episode_len:17
# kl:0.49895,lr_multiplier:7.594,loss:4.533393859863281,entropy:3.561951160430908,explained_var_old:0.000,explained_var_new:0.000
# batch i:183, episode_len:11
# kl:0.36677,lr_multiplier:5.062,loss:4.9735517501831055,entropy:3.2086479663848877,explained_var_old:0.000,explained_var_new:0.000
# batch i:184, episode_len:20
# kl:0.00160,lr_multiplier:7.594,loss:4.539767742156982,entropy:3.5614771842956543,explained_var_old:0.000,explained_var_new:0.000
# batch i:185, episode_len:17
# kl:0.00053,lr_multiplier:11.391,loss:4.538488388061523,entropy:3.5613553524017334,explained_var_old:0.000,explained_var_new:0.000
# batch i:186, episode_len:19
# kl:0.00089,lr_multiplier:11.391,loss:4.531883239746094,entropy:3.5603444576263428,explained_var_old:0.000,explained_var_new:0.000
# batch i:187, episode_len:15
# kl:0.00078,lr_multiplier:11.391,loss:4.534555435180664,entropy:3.560138463973999,explained_var_old:0.000,explained_var_new:0.000
# batch i:188, episode_len:18
# kl:0.00061,lr_multiplier:11.391,loss:4.524324417114258,entropy:3.5586321353912354,explained_var_old:0.000,explained_var_new:0.000
# batch i:189, episode_len:19
# kl:0.00076,lr_multiplier:11.391,loss:4.533722400665283,entropy:3.557158946990967,explained_var_old:0.000,explained_var_new:0.000
# batch i:190, episode_len:19
# kl:0.00049,lr_multiplier:11.391,loss:4.537534236907959,entropy:3.556689739227295,explained_var_old:0.000,explained_var_new:0.000
# batch i:191, episode_len:7
# kl:0.00046,lr_multiplier:11.391,loss:4.523520469665527,entropy:3.5558552742004395,explained_var_old:0.000,explained_var_new:0.000
# batch i:192, episode_len:16
# kl:0.00084,lr_multiplier:11.391,loss:4.530080795288086,entropy:3.5556416511535645,explained_var_old:0.000,explained_var_new:0.000
# batch i:193, episode_len:13
# kl:0.00070,lr_multiplier:11.391,loss:4.534146785736084,entropy:3.5555880069732666,explained_var_old:0.000,explained_var_new:0.000
# batch i:194, episode_len:26
# kl:0.00033,lr_multiplier:11.391,loss:4.522108554840088,entropy:3.557075262069702,explained_var_old:0.000,explained_var_new:0.000
# batch i:195, episode_len:11
# kl:0.00057,lr_multiplier:11.391,loss:4.517416000366211,entropy:3.5569612979888916,explained_var_old:0.000,explained_var_new:0.000
# batch i:196, episode_len:9
# kl:0.00059,lr_multiplier:11.391,loss:4.519586563110352,entropy:3.5556225776672363,explained_var_old:0.000,explained_var_new:0.000
# batch i:197, episode_len:28
# kl:0.00037,lr_multiplier:11.391,loss:4.530849933624268,entropy:3.5551836490631104,explained_var_old:0.000,explained_var_new:0.000
# batch i:198, episode_len:12
# kl:0.00040,lr_multiplier:11.391,loss:4.526401519775391,entropy:3.554382085800171,explained_var_old:0.000,explained_var_new:0.000
# batch i:199, episode_len:9
# kl:0.00053,lr_multiplier:11.391,loss:4.5315961837768555,entropy:3.5530972480773926,explained_var_old:0.000,explained_var_new:0.000
# batch i:200, episode_len:11
# kl:0.00061,lr_multiplier:11.391,loss:4.519074440002441,entropy:3.5516247749328613,explained_var_old:0.000,explained_var_new:0.000
# current self-play batch: 200
# num_playouts:1000, win: 1, lose: 9, tie:0
# batch i:201, episode_len:7
# kl:0.00049,lr_multiplier:11.391,loss:4.530973434448242,entropy:3.5517499446868896,explained_var_old:0.000,explained_var_new:0.000
# batch i:202, episode_len:13
# kl:0.00053,lr_multiplier:11.391,loss:4.523264408111572,entropy:3.5535433292388916,explained_var_old:0.000,explained_var_new:0.000
# batch i:203, episode_len:13
# kl:0.00078,lr_multiplier:11.391,loss:4.518723964691162,entropy:3.5552902221679688,explained_var_old:0.000,explained_var_new:0.000
# batch i:204, episode_len:9
# kl:0.00100,lr_multiplier:11.391,loss:4.528698444366455,entropy:3.555255651473999,explained_var_old:0.000,explained_var_new:0.000
# batch i:205, episode_len:12
# kl:0.00054,lr_multiplier:11.391,loss:4.522835731506348,entropy:3.5538411140441895,explained_var_old:0.000,explained_var_new:0.000
# batch i:206, episode_len:13
# kl:0.00104,lr_multiplier:11.391,loss:4.532318592071533,entropy:3.5522494316101074,explained_var_old:0.000,explained_var_new:0.000
# batch i:207, episode_len:11
# kl:0.00090,lr_multiplier:11.391,loss:4.532685279846191,entropy:3.5513272285461426,explained_var_old:0.000,explained_var_new:0.000
# batch i:208, episode_len:15
# kl:0.00100,lr_multiplier:11.391,loss:4.5240559577941895,entropy:3.551382303237915,explained_var_old:0.000,explained_var_new:0.000
# batch i:209, episode_len:16
# kl:0.00074,lr_multiplier:11.391,loss:4.534806251525879,entropy:3.5516703128814697,explained_var_old:0.000,explained_var_new:0.000
# batch i:210, episode_len:20
# kl:0.00115,lr_multiplier:11.391,loss:4.5357279777526855,entropy:3.5533254146575928,explained_var_old:0.000,explained_var_new:0.000
# batch i:211, episode_len:18
# kl:0.00078,lr_multiplier:11.391,loss:4.528409004211426,entropy:3.554565906524658,explained_var_old:0.000,explained_var_new:0.000
# batch i:212, episode_len:12
# kl:0.00066,lr_multiplier:11.391,loss:4.514072895050049,entropy:3.5534422397613525,explained_var_old:0.000,explained_var_new:0.000
# batch i:213, episode_len:20
# kl:0.00090,lr_multiplier:11.391,loss:4.529816627502441,entropy:3.551300287246704,explained_var_old:0.000,explained_var_new:0.000
# batch i:214, episode_len:18
# kl:0.00072,lr_multiplier:11.391,loss:4.528057098388672,entropy:3.5510060787200928,explained_var_old:0.000,explained_var_new:0.000
# batch i:215, episode_len:14
# kl:0.00094,lr_multiplier:11.391,loss:4.530570983886719,entropy:3.5516927242279053,explained_var_old:0.000,explained_var_new:0.000
# batch i:216, episode_len:23
# kl:0.00088,lr_multiplier:11.391,loss:4.533459186553955,entropy:3.5523037910461426,explained_var_old:0.000,explained_var_new:0.000
# batch i:217, episode_len:22
# kl:0.00085,lr_multiplier:11.391,loss:4.535366535186768,entropy:3.552856922149658,explained_var_old:0.000,explained_var_new:0.000
# batch i:218, episode_len:12
# kl:0.00063,lr_multiplier:11.391,loss:4.533268928527832,entropy:3.5536153316497803,explained_var_old:0.000,explained_var_new:0.000
# batch i:219, episode_len:13
# kl:0.00106,lr_multiplier:11.391,loss:4.513091087341309,entropy:3.5527913570404053,explained_var_old:0.000,explained_var_new:0.000
# batch i:220, episode_len:14
# kl:0.00088,lr_multiplier:11.391,loss:4.525575637817383,entropy:3.550049066543579,explained_var_old:0.000,explained_var_new:0.000
# batch i:221, episode_len:21
# kl:0.00055,lr_multiplier:11.391,loss:4.523062229156494,entropy:3.548818826675415,explained_var_old:0.000,explained_var_new:0.000
# batch i:222, episode_len:21
# kl:0.00098,lr_multiplier:11.391,loss:4.509931564331055,entropy:3.5490610599517822,explained_var_old:0.000,explained_var_new:0.000
# batch i:223, episode_len:15
# kl:0.00082,lr_multiplier:11.391,loss:4.533500671386719,entropy:3.5499539375305176,explained_var_old:0.000,explained_var_new:0.000
# batch i:224, episode_len:17
# kl:0.00062,lr_multiplier:11.391,loss:4.527379512786865,entropy:3.551361560821533,explained_var_old:0.000,explained_var_new:0.000
# batch i:225, episode_len:17
# kl:0.00070,lr_multiplier:11.391,loss:4.542724132537842,entropy:3.552295446395874,explained_var_old:0.000,explained_var_new:0.000
# batch i:226, episode_len:20
# kl:0.00064,lr_multiplier:11.391,loss:4.520256996154785,entropy:3.5521769523620605,explained_var_old:0.000,explained_var_new:0.000
# batch i:227, episode_len:13
# kl:0.00067,lr_multiplier:11.391,loss:4.526119709014893,entropy:3.5512921810150146,explained_var_old:0.000,explained_var_new:0.000
# batch i:228, episode_len:18
# kl:0.00072,lr_multiplier:11.391,loss:4.5290069580078125,entropy:3.550697088241577,explained_var_old:0.000,explained_var_new:0.000
# batch i:229, episode_len:20
# kl:0.00087,lr_multiplier:11.391,loss:4.521975517272949,entropy:3.550361394882202,explained_var_old:0.000,explained_var_new:0.000
# batch i:230, episode_len:27
# kl:0.00052,lr_multiplier:11.391,loss:4.511122703552246,entropy:3.550197124481201,explained_var_old:0.000,explained_var_new:0.000
# batch i:231, episode_len:19
# kl:0.00064,lr_multiplier:11.391,loss:4.523567199707031,entropy:3.5509188175201416,explained_var_old:0.000,explained_var_new:0.000
# batch i:232, episode_len:16
# kl:0.00134,lr_multiplier:11.391,loss:4.535289287567139,entropy:3.5519375801086426,explained_var_old:0.000,explained_var_new:0.000
# batch i:233, episode_len:20
# kl:0.00095,lr_multiplier:11.391,loss:4.516269683837891,entropy:3.5532569885253906,explained_var_old:0.000,explained_var_new:0.000
# batch i:234, episode_len:14
# kl:0.00051,lr_multiplier:11.391,loss:4.525637149810791,entropy:3.5532307624816895,explained_var_old:0.000,explained_var_new:0.000
# batch i:235, episode_len:9
# kl:0.00081,lr_multiplier:11.391,loss:4.520455360412598,entropy:3.552032947540283,explained_var_old:0.000,explained_var_new:0.000
# batch i:236, episode_len:21
# kl:0.00095,lr_multiplier:11.391,loss:4.521136283874512,entropy:3.5488202571868896,explained_var_old:0.000,explained_var_new:0.000
# batch i:237, episode_len:18
# kl:0.00070,lr_multiplier:11.391,loss:4.517897605895996,entropy:3.5475423336029053,explained_var_old:0.000,explained_var_new:0.000
# batch i:238, episode_len:13
# kl:0.00068,lr_multiplier:11.391,loss:4.521230220794678,entropy:3.5490224361419678,explained_var_old:0.000,explained_var_new:0.000
# batch i:239, episode_len:16
# kl:0.00087,lr_multiplier:11.391,loss:4.519110202789307,entropy:3.551563262939453,explained_var_old:0.000,explained_var_new:0.000
# batch i:240, episode_len:14
# kl:0.00115,lr_multiplier:11.391,loss:4.537844657897949,entropy:3.5547983646392822,explained_var_old:0.000,explained_var_new:0.000
# batch i:241, episode_len:12
# kl:0.00075,lr_multiplier:11.391,loss:4.546224117279053,entropy:3.5562288761138916,explained_var_old:0.000,explained_var_new:0.000
# batch i:242, episode_len:19
# kl:0.00091,lr_multiplier:11.391,loss:4.554612159729004,entropy:3.5559232234954834,explained_var_old:0.000,explained_var_new:0.000
# batch i:243, episode_len:19
# kl:0.00108,lr_multiplier:11.391,loss:4.554769515991211,entropy:3.5539438724517822,explained_var_old:0.000,explained_var_new:0.000
# batch i:244, episode_len:16
# kl:0.00070,lr_multiplier:11.391,loss:4.558104515075684,entropy:3.5526926517486572,explained_var_old:0.000,explained_var_new:0.000
# batch i:245, episode_len:15
# kl:0.00081,lr_multiplier:11.391,loss:4.553145408630371,entropy:3.5529818534851074,explained_var_old:0.000,explained_var_new:0.000
# batch i:246, episode_len:21
# kl:0.00081,lr_multiplier:11.391,loss:4.5515971183776855,entropy:3.5519938468933105,explained_var_old:0.000,explained_var_new:0.000
# batch i:247, episode_len:22
# kl:0.00057,lr_multiplier:11.391,loss:4.552499771118164,entropy:3.5512163639068604,explained_var_old:0.000,explained_var_new:0.000
# batch i:248, episode_len:10
# kl:0.00064,lr_multiplier:11.391,loss:4.552328109741211,entropy:3.552198648452759,explained_var_old:0.000,explained_var_new:0.000
# batch i:249, episode_len:15
# kl:0.00057,lr_multiplier:11.391,loss:4.536324977874756,entropy:3.5520596504211426,explained_var_old:0.000,explained_var_new:0.000
# batch i:250, episode_len:12
# kl:0.00053,lr_multiplier:11.391,loss:4.547220230102539,entropy:3.5510220527648926,explained_var_old:0.000,explained_var_new:0.000
# current self-play batch: 250
# num_playouts:1000, win: 1, lose: 9, tie:0
# batch i:251, episode_len:17
# kl:0.00064,lr_multiplier:11.391,loss:4.551784038543701,entropy:3.549773693084717,explained_var_old:0.000,explained_var_new:0.000
# batch i:252, episode_len:15
# kl:0.00041,lr_multiplier:11.391,loss:4.552626609802246,entropy:3.5498158931732178,explained_var_old:0.000,explained_var_new:0.000
# batch i:253, episode_len:23
# kl:0.00078,lr_multiplier:11.391,loss:4.5460052490234375,entropy:3.550506830215454,explained_var_old:0.000,explained_var_new:0.000
# batch i:254, episode_len:11
# kl:0.00102,lr_multiplier:11.391,loss:4.548701286315918,entropy:3.5486409664154053,explained_var_old:0.000,explained_var_new:0.000
# batch i:255, episode_len:19
# kl:0.00062,lr_multiplier:11.391,loss:4.556097984313965,entropy:3.547459125518799,explained_var_old:0.000,explained_var_new:0.000
# batch i:256, episode_len:15
# kl:0.00095,lr_multiplier:11.391,loss:4.551419258117676,entropy:3.548471212387085,explained_var_old:0.000,explained_var_new:0.000
# batch i:257, episode_len:10
# kl:0.00115,lr_multiplier:11.391,loss:4.545178413391113,entropy:3.5476417541503906,explained_var_old:0.000,explained_var_new:0.000
# batch i:258, episode_len:21
# kl:0.00061,lr_multiplier:11.391,loss:4.547596454620361,entropy:3.5452113151550293,explained_var_old:0.000,explained_var_new:0.000
# batch i:259, episode_len:18
# kl:0.00061,lr_multiplier:11.391,loss:4.549737453460693,entropy:3.544642925262451,explained_var_old:0.000,explained_var_new:0.000
# batch i:260, episode_len:14
# kl:0.00084,lr_multiplier:11.391,loss:4.542390823364258,entropy:3.5443150997161865,explained_var_old:0.000,explained_var_new:0.000
# batch i:261, episode_len:17
# kl:0.00089,lr_multiplier:11.391,loss:4.545169353485107,entropy:3.5433809757232666,explained_var_old:0.000,explained_var_new:0.000
# batch i:262, episode_len:18
# kl:0.00090,lr_multiplier:11.391,loss:4.544677734375,entropy:3.5440902709960938,explained_var_old:0.000,explained_var_new:0.000
# batch i:263, episode_len:14
# kl:0.00082,lr_multiplier:11.391,loss:4.535182952880859,entropy:3.5450594425201416,explained_var_old:0.000,explained_var_new:0.000
# batch i:264, episode_len:12
# kl:0.00065,lr_multiplier:11.391,loss:4.553359031677246,entropy:3.546699047088623,explained_var_old:0.000,explained_var_new:0.000
# batch i:265, episode_len:18
# kl:0.00100,lr_multiplier:11.391,loss:4.545647621154785,entropy:3.5479886531829834,explained_var_old:0.000,explained_var_new:0.000
# batch i:266, episode_len:10
# kl:0.00115,lr_multiplier:11.391,loss:4.543386936187744,entropy:3.545978307723999,explained_var_old:0.000,explained_var_new:0.000
# batch i:267, episode_len:24
# kl:0.00075,lr_multiplier:11.391,loss:4.551485061645508,entropy:3.5433311462402344,explained_var_old:0.000,explained_var_new:0.000
# batch i:268, episode_len:14
# kl:0.00074,lr_multiplier:11.391,loss:4.544676780700684,entropy:3.542064666748047,explained_var_old:0.000,explained_var_new:0.000
# batch i:269, episode_len:15
# kl:0.00047,lr_multiplier:11.391,loss:4.540605068206787,entropy:3.5424273014068604,explained_var_old:0.000,explained_var_new:0.000
# batch i:270, episode_len:16
# kl:0.00082,lr_multiplier:11.391,loss:4.544333457946777,entropy:3.544872760772705,explained_var_old:0.000,explained_var_new:0.000
# batch i:271, episode_len:22
# kl:0.00075,lr_multiplier:11.391,loss:4.547209739685059,entropy:3.5470385551452637,explained_var_old:0.000,explained_var_new:0.000
# batch i:272, episode_len:17
# kl:0.00075,lr_multiplier:11.391,loss:4.538504123687744,entropy:3.546471118927002,explained_var_old:0.000,explained_var_new:0.000
# batch i:273, episode_len:19
# kl:0.00092,lr_multiplier:11.391,loss:4.5407514572143555,entropy:3.5431325435638428,explained_var_old:0.000,explained_var_new:0.000
# batch i:274, episode_len:13
# kl:0.00080,lr_multiplier:11.391,loss:4.544511795043945,entropy:3.5412330627441406,explained_var_old:0.000,explained_var_new:0.000
# batch i:275, episode_len:14
# kl:0.00091,lr_multiplier:11.391,loss:4.548941135406494,entropy:3.542052745819092,explained_var_old:0.000,explained_var_new:0.000
# batch i:276, episode_len:11
# kl:0.00093,lr_multiplier:11.391,loss:4.551520824432373,entropy:3.544945001602173,explained_var_old:0.000,explained_var_new:0.000
# batch i:277, episode_len:12
# kl:0.00103,lr_multiplier:11.391,loss:4.552180290222168,entropy:3.5487329959869385,explained_var_old:0.000,explained_var_new:0.000
# batch i:278, episode_len:14
# kl:0.00071,lr_multiplier:11.391,loss:4.5427045822143555,entropy:3.550224781036377,explained_var_old:0.000,explained_var_new:0.000
# batch i:279, episode_len:12
# kl:0.00083,lr_multiplier:11.391,loss:4.5528459548950195,entropy:3.5487306118011475,explained_var_old:0.000,explained_var_new:0.000
# batch i:280, episode_len:21
# kl:0.00087,lr_multiplier:11.391,loss:4.547574996948242,entropy:3.5458757877349854,explained_var_old:0.000,explained_var_new:0.000
# batch i:281, episode_len:12
# kl:0.00076,lr_multiplier:11.391,loss:4.539312362670898,entropy:3.5423810482025146,explained_var_old:0.000,explained_var_new:0.000
# batch i:282, episode_len:22
# kl:0.00056,lr_multiplier:11.391,loss:4.547053337097168,entropy:3.5397908687591553,explained_var_old:0.000,explained_var_new:0.000
# batch i:283, episode_len:15
# kl:0.00071,lr_multiplier:11.391,loss:4.555915355682373,entropy:3.5432629585266113,explained_var_old:0.000,explained_var_new:0.000
# batch i:284, episode_len:13
# kl:0.00097,lr_multiplier:11.391,loss:4.539261341094971,entropy:3.547417163848877,explained_var_old:0.000,explained_var_new:0.000
# batch i:285, episode_len:21
# kl:0.00119,lr_multiplier:11.391,loss:4.545401573181152,entropy:3.5462758541107178,explained_var_old:0.000,explained_var_new:0.000
# batch i:286, episode_len:13
# kl:0.00094,lr_multiplier:11.391,loss:4.541123867034912,entropy:3.5426976680755615,explained_var_old:0.000,explained_var_new:0.000
# batch i:287, episode_len:10
# kl:0.00086,lr_multiplier:11.391,loss:4.556997299194336,entropy:3.54194974899292,explained_var_old:0.000,explained_var_new:0.000
# batch i:288, episode_len:15
# kl:0.00141,lr_multiplier:11.391,loss:4.548581123352051,entropy:3.5452075004577637,explained_var_old:0.000,explained_var_new:0.000
# batch i:289, episode_len:13
# kl:0.00128,lr_multiplier:11.391,loss:4.546341896057129,entropy:3.547555685043335,explained_var_old:0.000,explained_var_new:0.000
# batch i:290, episode_len:14
# kl:0.00102,lr_multiplier:11.391,loss:4.548383712768555,entropy:3.548919439315796,explained_var_old:0.000,explained_var_new:0.000
# batch i:291, episode_len:11
# kl:0.00079,lr_multiplier:11.391,loss:4.560735702514648,entropy:3.550842523574829,explained_var_old:0.000,explained_var_new:0.000
# batch i:292, episode_len:12
# kl:0.00112,lr_multiplier:11.391,loss:4.5526509284973145,entropy:3.552623748779297,explained_var_old:0.000,explained_var_new:0.000
# batch i:293, episode_len:18
# kl:0.00088,lr_multiplier:11.391,loss:4.550580024719238,entropy:3.551487445831299,explained_var_old:0.000,explained_var_new:0.000
# batch i:294, episode_len:12
# kl:0.00090,lr_multiplier:11.391,loss:4.548004150390625,entropy:3.5487287044525146,explained_var_old:0.000,explained_var_new:0.000
# batch i:295, episode_len:27
# kl:0.00051,lr_multiplier:11.391,loss:4.547452926635742,entropy:3.546818256378174,explained_var_old:0.000,explained_var_new:0.000
# batch i:296, episode_len:9
# kl:0.00088,lr_multiplier:11.391,loss:4.540390491485596,entropy:3.546783685684204,explained_var_old:0.000,explained_var_new:0.000
# batch i:297, episode_len:13
# kl:0.00122,lr_multiplier:11.391,loss:4.555192947387695,entropy:3.546077251434326,explained_var_old:0.000,explained_var_new:0.000
# batch i:298, episode_len:19
# kl:0.00085,lr_multiplier:11.391,loss:4.538866996765137,entropy:3.544151782989502,explained_var_old:0.000,explained_var_new:0.000
# batch i:299, episode_len:13
# kl:0.00067,lr_multiplier:11.391,loss:4.541092872619629,entropy:3.541919469833374,explained_var_old:0.000,explained_var_new:0.000
# batch i:300, episode_len:22
# kl:0.00065,lr_multiplier:11.391,loss:4.540274143218994,entropy:3.5402562618255615,explained_var_old:0.000,explained_var_new:0.000
# current self-play batch: 300
# num_playouts:1000, win: 2, lose: 8, tie:0
# batch i:301, episode_len:10
# kl:0.00096,lr_multiplier:11.391,loss:4.531243801116943,entropy:3.537353754043579,explained_var_old:0.000,explained_var_new:0.000
# batch i:302, episode_len:22
# ...
# current self-play batch: 400
# num_playouts:1000, win: 1, lose: 9, tie:0
# batch i:401, episode_len:11
# kl:0.00073,lr_multiplier:11.391,loss:4.496708869934082,entropy:3.532731771469116,explained_var_old:0.000,explained_var_new:0.000
# batch i:402, episode_len:25
# kl:0.00086,lr_multiplier:11.391,loss:4.510287284851074,entropy:3.532623529434204,explained_var_old:0.000,explained_var_new:0.000
# batch i:403, episode_len:12
# kl:0.00071,lr_multiplier:11.391,loss:4.500826835632324,entropy:3.535194158554077,explained_var_old:0.000,explained_var_new:0.000
# batch i:404, episode_len:11
# kl:0.00101,lr_multiplier:11.391,loss:4.514415740966797,entropy:3.539337396621704,explained_var_old:0.000,explained_var_new:0.000
# batch i:405, episode_len:13
# kl:0.00069,lr_multiplier:11.391,loss:4.494601249694824,entropy:3.542651891708374,explained_var_old:0.000,explained_var_new:0.000
# batch i:406, episode_len:15
# kl:0.00086,lr_multiplier:11.391,loss:4.50277853012085,entropy:3.5418283939361572,explained_var_old:0.000,explained_var_new:0.000
# batch i:407, episode_len:14
# kl:0.00060,lr_multiplier:11.391,loss:4.488868713378906,entropy:3.5369954109191895,explained_var_old:0.000,explained_var_new:0.000
# batch i:408, episode_len:10
# kl:0.00069,lr_multiplier:11.391,loss:4.4998779296875,entropy:3.531463146209717,explained_var_old:0.000,explained_var_new:0.000
# batch i:409, episode_len:16
# kl:0.00063,lr_multiplier:11.391,loss:4.491680145263672,entropy:3.5270955562591553,explained_var_old:0.000,explained_var_new:0.000
# batch i:410, episode_len:15
# kl:0.00057,lr_multiplier:11.391,loss:4.506608963012695,entropy:3.5267415046691895,explained_var_old:0.000,explained_var_new:0.000
# batch i:411, episode_len:12
# kl:0.00074,lr_multiplier:11.391,loss:4.493772506713867,entropy:3.5287744998931885,explained_var_old:0.000,explained_var_new:0.000
# batch i:412, episode_len:17
# kl:0.00059,lr_multiplier:11.391,loss:4.512041091918945,entropy:3.530952215194702,explained_var_old:0.000,explained_var_new:0.000
# batch i:413, episode_len:14
# kl:0.00073,lr_multiplier:11.391,loss:4.504180908203125,entropy:3.534149646759033,explained_var_old:0.000,explained_var_new:0.000
# batch i:414, episode_len:16
# kl:0.00096,lr_multiplier:11.391,loss:4.50546407699585,entropy:3.536109685897827,explained_var_old:0.000,explained_var_new:0.000
# batch i:415, episode_len:10
# kl:0.00085,lr_multiplier:11.391,loss:4.51408576965332,entropy:3.5383317470550537,explained_var_old:0.000,explained_var_new:0.000
# batch i:416, episode_len:15
# kl:0.00082,lr_multiplier:11.391,loss:4.507317543029785,entropy:3.5400235652923584,explained_var_old:0.000,explained_var_new:0.000
# batch i:417, episode_len:14
# kl:0.00056,lr_multiplier:11.391,loss:4.493155479431152,entropy:3.5384974479675293,explained_var_old:0.000,explained_var_new:0.000
# batch i:418, episode_len:13
# kl:0.00074,lr_multiplier:11.391,loss:4.48685884475708,entropy:3.5357508659362793,explained_var_old:0.000,explained_var_new:0.000
# batch i:419, episode_len:11
# kl:0.00064,lr_multiplier:11.391,loss:4.5170464515686035,entropy:3.5322458744049072,explained_var_old:0.000,explained_var_new:0.000
# batch i:420, episode_len:18
# kl:0.00083,lr_multiplier:11.391,loss:4.501691818237305,entropy:3.527374505996704,explained_var_old:0.000,explained_var_new:0.000
# batch i:421, episode_len:13
# kl:0.00112,lr_multiplier:11.391,loss:4.510885238647461,entropy:3.5239405632019043,explained_var_old:0.000,explained_var_new:0.000
# batch i:422, episode_len:13
# kl:0.00067,lr_multiplier:11.391,loss:4.498592376708984,entropy:3.5265467166900635,explained_var_old:0.000,explained_var_new:0.000
# batch i:423, episode_len:14
# kl:0.00127,lr_multiplier:11.391,loss:4.529326915740967,entropy:3.534080743789673,explained_var_old:0.000,explained_var_new:0.000
# batch i:424, episode_len:16
# kl:0.00075,lr_multiplier:11.391,loss:4.5067572593688965,entropy:3.538696527481079,explained_var_old:0.000,explained_var_new:0.000
# batch i:425, episode_len:14
# kl:0.00084,lr_multiplier:11.391,loss:4.502850532531738,entropy:3.538403034210205,explained_var_old:0.000,explained_var_new:0.000
# batch i:426, episode_len:20
# kl:0.00079,lr_multiplier:11.391,loss:4.5037922859191895,entropy:3.5357022285461426,explained_var_old:0.000,explained_var_new:0.000
# batch i:427, episode_len:7
# kl:0.00073,lr_multiplier:11.391,loss:4.516518592834473,entropy:3.5350148677825928,explained_var_old:0.000,explained_var_new:0.000
# batch i:428, episode_len:16
# kl:0.00074,lr_multiplier:11.391,loss:4.508548259735107,entropy:3.536639928817749,explained_var_old:0.000,explained_var_new:0.000
# batch i:429, episode_len:11
# kl:0.00101,lr_multiplier:11.391,loss:4.508320331573486,entropy:3.5358738899230957,explained_var_old:0.000,explained_var_new:0.000
# batch i:430, episode_len:17
# kl:0.00091,lr_multiplier:11.391,loss:4.49594783782959,entropy:3.5340611934661865,explained_var_old:0.000,explained_var_new:0.000
# batch i:431, episode_len:17
# kl:0.00089,lr_multiplier:11.391,loss:4.515300750732422,entropy:3.5331459045410156,explained_var_old:0.000,explained_var_new:0.000
# batch i:432, episode_len:20
# kl:0.00075,lr_multiplier:11.391,loss:4.516439914703369,entropy:3.5334432125091553,explained_var_old:0.000,explained_var_new:0.000
# batch i:433, episode_len:12
# kl:0.00072,lr_multiplier:11.391,loss:4.5121660232543945,entropy:3.5362281799316406,explained_var_old:0.000,explained_var_new:0.000
# batch i:434, episode_len:14
# kl:0.00095,lr_multiplier:11.391,loss:4.508189678192139,entropy:3.539764642715454,explained_var_old:0.000,explained_var_new:0.000
# batch i:435, episode_len:14
# kl:0.00076,lr_multiplier:11.391,loss:4.524244785308838,entropy:3.5396840572357178,explained_var_old:0.000,explained_var_new:0.000
# batch i:436, episode_len:19
# kl:0.00063,lr_multiplier:11.391,loss:4.501036643981934,entropy:3.5386412143707275,explained_var_old:0.000,explained_var_new:0.000
# batch i:437, episode_len:14
# kl:0.00080,lr_multiplier:11.391,loss:4.513528347015381,entropy:3.537208080291748,explained_var_old:0.000,explained_var_new:0.000
# batch i:438, episode_len:13
# kl:0.00068,lr_multiplier:11.391,loss:4.515744686126709,entropy:3.534912109375,explained_var_old:0.000,explained_var_new:0.000
# batch i:439, episode_len:9
# kl:0.00068,lr_multiplier:11.391,loss:4.5123491287231445,entropy:3.5346598625183105,explained_var_old:0.000,explained_var_new:0.000
# batch i:440, episode_len:22
# kl:0.00057,lr_multiplier:11.391,loss:4.5082597732543945,entropy:3.5346827507019043,explained_var_old:0.000,explained_var_new:0.000
# batch i:441, episode_len:13
# kl:0.00061,lr_multiplier:11.391,loss:4.504732131958008,entropy:3.5344815254211426,explained_var_old:0.000,explained_var_new:0.000
# batch i:442, episode_len:11
# kl:0.00047,lr_multiplier:11.391,loss:4.525661945343018,entropy:3.535011053085327,explained_var_old:0.000,explained_var_new:0.000
# batch i:443, episode_len:20
# kl:0.00060,lr_multiplier:11.391,loss:4.499141216278076,entropy:3.5371968746185303,explained_var_old:0.000,explained_var_new:0.000
# batch i:444, episode_len:11
# kl:0.00082,lr_multiplier:11.391,loss:4.528584957122803,entropy:3.540588140487671,explained_var_old:0.000,explained_var_new:0.000
# batch i:445, episode_len:20
# kl:0.00078,lr_multiplier:11.391,loss:4.515476226806641,entropy:3.5412003993988037,explained_var_old:0.000,explained_var_new:0.000
# batch i:446, episode_len:14
# kl:0.00055,lr_multiplier:11.391,loss:4.48977518081665,entropy:3.5370371341705322,explained_var_old:0.000,explained_var_new:0.000
# batch i:447, episode_len:10
# kl:0.00046,lr_multiplier:11.391,loss:4.535311698913574,entropy:3.5351107120513916,explained_var_old:0.000,explained_var_new:0.000
# batch i:448, episode_len:20
# kl:0.00109,lr_multiplier:11.391,loss:4.500055313110352,entropy:3.5359952449798584,explained_var_old:0.000,explained_var_new:0.000
# batch i:449, episode_len:9
# kl:0.00073,lr_multiplier:11.391,loss:4.526740550994873,entropy:3.5379831790924072,explained_var_old:0.000,explained_var_new:0.000
# batch i:450, episode_len:13
# kl:0.00043,lr_multiplier:11.391,loss:4.518857479095459,entropy:3.5414767265319824,explained_var_old:0.000,explained_var_new:0.000
# current self-play batch: 450
# num_playouts:1000, win: 1, lose: 9, tie:0
# batch i:451, episode_len:16
# kl:0.00064,lr_multiplier:11.391,loss:4.507111549377441,entropy:3.5429799556732178,explained_var_old:0.000,explained_var_new:0.000
# batch i:452, episode_len:21
# kl:0.00070,lr_multiplier:11.391,loss:4.5203142166137695,entropy:3.542903423309326,explained_var_old:0.000,explained_var_new:0.000
# batch i:453, episode_len:19
# kl:0.00070,lr_multiplier:11.391,loss:4.518595218658447,entropy:3.5405688285827637,explained_var_old:0.000,explained_var_new:0.000
# batch i:454, episode_len:15
# kl:0.00131,lr_multiplier:11.391,loss:4.507250785827637,entropy:3.5367205142974854,explained_var_old:0.000,explained_var_new:0.000
# batch i:455, episode_len:12
# kl:0.00098,lr_multiplier:11.391,loss:4.518721580505371,entropy:3.5363657474517822,explained_var_old:0.000,explained_var_new:0.000
# batch i:456, episode_len:15
# kl:0.00098,lr_multiplier:11.391,loss:4.5188212394714355,entropy:3.5387189388275146,explained_var_old:0.000,explained_var_new:0.000
# batch i:457, episode_len:11
# kl:0.00095,lr_multiplier:11.391,loss:4.4953508377075195,entropy:3.538288116455078,explained_var_old:0.000,explained_var_new:0.000
# batch i:458, episode_len:25
# kl:0.00064,lr_multiplier:11.391,loss:4.51180362701416,entropy:3.535447835922241,explained_var_old:0.000,explained_var_new:0.000
# batch i:459, episode_len:13
# kl:0.00065,lr_multiplier:11.391,loss:4.515615463256836,entropy:3.5346484184265137,explained_var_old:0.000,explained_var_new:0.000
# batch i:460, episode_len:25
# kl:0.00059,lr_multiplier:11.391,loss:4.49482536315918,entropy:3.53599214553833,explained_var_old:0.000,explained_var_new:0.000
# batch i:461, episode_len:19
# kl:0.00066,lr_multiplier:11.391,loss:4.5175676345825195,entropy:3.5369296073913574,explained_var_old:0.000,explained_var_new:0.000
# batch i:462, episode_len:19
# kl:0.00099,lr_multiplier:11.391,loss:4.511007785797119,entropy:3.5384554862976074,explained_var_old:0.000,explained_var_new:0.000
# batch i:463, episode_len:15
# kl:0.00118,lr_multiplier:11.391,loss:4.495360374450684,entropy:3.5388529300689697,explained_var_old:0.000,explained_var_new:0.000
# batch i:464, episode_len:13
# kl:0.00094,lr_multiplier:11.391,loss:4.509213924407959,entropy:3.5350232124328613,explained_var_old:0.000,explained_var_new:0.000
# batch i:465, episode_len:13
# kl:0.00093,lr_multiplier:11.391,loss:4.51373815536499,entropy:3.5335042476654053,explained_var_old:0.000,explained_var_new:0.000
# batch i:466, episode_len:26
# kl:0.00107,lr_multiplier:11.391,loss:4.504913330078125,entropy:3.535709857940674,explained_var_old:0.000,explained_var_new:0.000
# batch i:467, episode_len:11
# kl:0.00087,lr_multiplier:11.391,loss:4.518383979797363,entropy:3.5359690189361572,explained_var_old:0.000,explained_var_new:0.000
# batch i:468, episode_len:25
# kl:0.00052,lr_multiplier:11.391,loss:4.499934196472168,entropy:3.534623861312866,explained_var_old:0.000,explained_var_new:0.000
# batch i:469, episode_len:13
# kl:0.00076,lr_multiplier:11.391,loss:4.522100448608398,entropy:3.533237934112549,explained_var_old:0.000,explained_var_new:0.000
# batch i:470, episode_len:7
# kl:0.00063,lr_multiplier:11.391,loss:4.520419597625732,entropy:3.5328176021575928,explained_var_old:0.000,explained_var_new:0.000
# batch i:471, episode_len:17
# kl:0.00057,lr_multiplier:11.391,loss:4.510410308837891,entropy:3.532349109649658,explained_var_old:0.000,explained_var_new:0.000
# batch i:472, episode_len:10
# kl:0.00067,lr_multiplier:11.391,loss:4.534494876861572,entropy:3.532844305038452,explained_var_old:0.000,explained_var_new:0.000
# batch i:473, episode_len:17
# kl:0.00092,lr_multiplier:11.391,loss:4.532626152038574,entropy:3.5333666801452637,explained_var_old:0.000,explained_var_new:0.000
# batch i:474, episode_len:16
# kl:0.00091,lr_multiplier:11.391,loss:4.5342888832092285,entropy:3.5318870544433594,explained_var_old:0.000,explained_var_new:0.000
# batch i:475, episode_len:16
# kl:0.00068,lr_multiplier:11.391,loss:4.535089492797852,entropy:3.5306742191314697,explained_var_old:0.000,explained_var_new:0.000
# batch i:476, episode_len:10
# kl:0.00071,lr_multiplier:11.391,loss:4.5313801765441895,entropy:3.530608892440796,explained_var_old:0.000,explained_var_new:0.000
# batch i:477, episode_len:13
# kl:0.00070,lr_multiplier:11.391,loss:4.543050765991211,entropy:3.5330121517181396,explained_var_old:0.000,explained_var_new:0.000
# batch i:478, episode_len:15
# kl:0.00089,lr_multiplier:11.391,loss:4.51891565322876,entropy:3.5355188846588135,explained_var_old:0.000,explained_var_new:0.000
# batch i:479, episode_len:12
# kl:0.00130,lr_multiplier:11.391,loss:4.5313334465026855,entropy:3.534461736679077,explained_var_old:0.000,explained_var_new:0.000
# batch i:480, episode_len:20
# kl:0.00060,lr_multiplier:11.391,loss:4.538095474243164,entropy:3.5340540409088135,explained_var_old:0.000,explained_var_new:0.000
# batch i:481, episode_len:12
# kl:0.00092,lr_multiplier:11.391,loss:4.537223815917969,entropy:3.536029577255249,explained_var_old:0.000,explained_var_new:0.000
# batch i:482, episode_len:15
# kl:0.00131,lr_multiplier:11.391,loss:4.528486251831055,entropy:3.535613775253296,explained_var_old:0.000,explained_var_new:0.000
# batch i:483, episode_len:16
# kl:0.00076,lr_multiplier:11.391,loss:4.528438091278076,entropy:3.5305159091949463,explained_var_old:0.000,explained_var_new:0.000
# batch i:484, episode_len:12
# kl:0.00066,lr_multiplier:11.391,loss:4.53223991394043,entropy:3.5265772342681885,explained_var_old:0.000,explained_var_new:0.000
# batch i:485, episode_len:13
# kl:0.00096,lr_multiplier:11.391,loss:4.52771520614624,entropy:3.525512933731079,explained_var_old:0.000,explained_var_new:0.000
# batch i:486, episode_len:21
# kl:0.00098,lr_multiplier:11.391,loss:4.543880939483643,entropy:3.5287091732025146,explained_var_old:0.000,explained_var_new:0.000
# batch i:487, episode_len:11
# kl:0.00127,lr_multiplier:11.391,loss:4.530551910400391,entropy:3.534167766571045,explained_var_old:0.000,explained_var_new:0.000
# batch i:488, episode_len:18
# kl:0.00105,lr_multiplier:11.391,loss:4.523311138153076,entropy:3.533722162246704,explained_var_old:0.000,explained_var_new:0.000
# batch i:489, episode_len:11
# kl:0.00085,lr_multiplier:11.391,loss:4.531060695648193,entropy:3.5298917293548584,explained_var_old:0.000,explained_var_new:0.000
# batch i:490, episode_len:21
# kl:0.00102,lr_multiplier:11.391,loss:4.532567024230957,entropy:3.5275228023529053,explained_var_old:0.000,explained_var_new:0.000
# batch i:491, episode_len:18
# kl:0.00080,lr_multiplier:11.391,loss:4.53046989440918,entropy:3.5274126529693604,explained_var_old:0.000,explained_var_new:0.000
# batch i:492, episode_len:15
# kl:0.00088,lr_multiplier:11.391,loss:4.529353618621826,entropy:3.5276505947113037,explained_var_old:0.000,explained_var_new:0.000
# batch i:493, episode_len:18
# kl:0.00105,lr_multiplier:11.391,loss:4.534787178039551,entropy:3.5282247066497803,explained_var_old:0.000,explained_var_new:0.000
# batch i:494, episode_len:19
# kl:0.00075,lr_multiplier:11.391,loss:4.536486625671387,entropy:3.5309507846832275,explained_var_old:0.000,explained_var_new:0.000
# batch i:495, episode_len:21
# kl:0.00081,lr_multiplier:11.391,loss:4.539458274841309,entropy:3.534820318222046,explained_var_old:0.000,explained_var_new:0.000
# batch i:496, episode_len:14
# kl:0.00065,lr_multiplier:11.391,loss:4.512520790100098,entropy:3.5349392890930176,explained_var_old:0.000,explained_var_new:0.000
# batch i:497, episode_len:13
# kl:0.00051,lr_multiplier:11.391,loss:4.531827449798584,entropy:3.530738592147827,explained_var_old:0.000,explained_var_new:0.000
# batch i:498, episode_len:26
# kl:0.00071,lr_multiplier:11.391,loss:4.519710063934326,entropy:3.5269885063171387,explained_var_old:0.000,explained_var_new:0.000
# batch i:499, episode_len:14
# kl:0.00061,lr_multiplier:11.391,loss:4.537684917449951,entropy:3.527305841445923,explained_var_old:0.000,explained_var_new:0.000
# batch i:500, episode_len:30
# kl:0.00047,lr_multiplier:11.391,loss:4.528594970703125,entropy:3.531799554824829,explained_var_old:0.000,explained_var_new:0.000
# current self-play batch: 500
# num_playouts:1000, win: 2, lose: 8, tie:0
